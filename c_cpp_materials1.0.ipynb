# %% [markdown]
# ## Roadmap kiến thức (theo chủ đề thi)
#
# | Chủ đề thi | Chương/Mục tương ứng |
# | --- | --- |
# | Cơ bản: cấu trúc chương trình, comment, printf | Chương 1 |
# | Biến, kiểu dữ liệu, hằng, sizeof, định dạng in | Chương 2 |
# | Toán tử, biểu thức, ?:, ++/-- | Chương 3 |
# | Điều khiển luồng: if/else, switch, vòng lặp | Chương 4 |
# | Hàm, prototype, phạm vi | Chương 5 |
# | Mảng 1D/2D, khởi tạo | Chương 6 |
# | Địa chỉ bộ nhớ, con trỏ, scanf | Chương 7 |
# | Con trỏ & mảng, con trỏ hàm | Chương 8 |
# | Chuỗi C, string.h, bộ đệm | Chương 9 |
# | Cấp phát động malloc/free | Chương 10 |
# | struct, enum, typedef, padding | Chương 11 |
# | File I/O trong C (FILE/FILE*) | Chương 12 |
# | Toán tử bit | Chương 13 |
# | C++ cơ bản: iostream, string, tham chiếu, nạp chồng | Chương 14 |
# | Lớp, constructor/destructor | Chương 15 |
# | new/delete, RAII, smart pointer | Chương 16 |
# | Kế thừa, đa hình, virtual | Chương 17 |
# | Template, STL (vector, map) | Chương 18 |
# | File I/O trong C++ | Chương 19 |
# | Friend function/class | Chương 20 |
# | Tổng ôn & mini-mock test | Cuối notebook |

# %% [markdown]
# ## Mục lục
# - [Chương 1. Cơ bản: cấu trúc chương trình và xuất dữ liệu](#ch1)
# - [Chương 2. Biến, kiểu dữ liệu, hằng, sizeof, định dạng in](#ch2)
# - [Chương 3. Toán tử và biểu thức](#ch3)
# - [Chương 4. Điều khiển luồng](#ch4)
# - [Chương 5. Hàm và phạm vi](#ch5)
# - [Chương 6. Mảng 1D/2D](#ch6)
# - [Chương 7. Địa chỉ bộ nhớ và con trỏ cơ bản](#ch7)
# - [Chương 8. Con trỏ & mảng, con trỏ hàm](#ch8)
# - [Chương 9. Chuỗi C và xử lý chuỗi](#ch9)
# - [Chương 10. Cấp phát bộ nhớ động](#ch10)
# - [Chương 11. struct, enum, typedef](#ch11)
# - [Chương 12. File I/O trong C](#ch12)
# - [Chương 13. Toán tử bit](#ch13)
# - [Chương 14. C++ cơ bản](#ch14)
# - [Chương 15. Lớp, constructor, destructor](#ch15)
# - [Chương 16. new/delete và RAII](#ch16)
# - [Chương 17. Kế thừa và đa hình](#ch17)
# - [Chương 18. Template và STL](#ch18)
# - [Chương 19. File I/O trong C++](#ch19)
# - [Chương 20. Friend function/class](#ch20)
# - [Tổng ôn theo format đề thi](#review)
#
# - [Mini-Mock theo Chương](#mini-mock-theo-chuong)
# - [Mock Chương 1 (15 câu)](#mock-chuong-1-15-cau)
# - [Mock Chương 2 (15 câu)](#mock-chuong-2-15-cau)
# - [Mock Chương 3 (15 câu)](#mock-chuong-3-15-cau)
# - [Mock Chương 4 (15 câu)](#mock-chuong-4-15-cau)
# - [Mock Chương 5 (15 câu)](#mock-chuong-5-15-cau)
# - [Mock Chương 6 (15 câu)](#mock-chuong-6-15-cau)
# - [Mock Chương 7 (15 câu)](#mock-chuong-7-15-cau)
# - [Mock Chương 8 (15 câu)](#mock-chuong-8-15-cau)
# - [Mock Chương 9 (15 câu)](#mock-chuong-9-15-cau)
# - [Mock Chương 10 (15 câu)](#mock-chuong-10-15-cau)
# - [Mock Chương 11 (15 câu)](#mock-chuong-11-15-cau)
# - [Mock Chương 12 (15 câu)](#mock-chuong-12-15-cau)
# - [Mock Chương 13 (15 câu)](#mock-chuong-13-15-cau)
# - [Mock Chương 14 (15 câu)](#mock-chuong-14-15-cau)
# - [Mock Chương 15 (15 câu)](#mock-chuong-15-15-cau)
# - [Mock Chương 16 (15 câu)](#mock-chuong-16-15-cau)
# - [Mock Chương 17 (15 câu)](#mock-chuong-17-15-cau)
# - [Mock Chương 18 (15 câu)](#mock-chuong-18-15-cau)
# - [Mock Chương 19 (15 câu)](#mock-chuong-19-15-cau)
# - [Mock Chương 20 (15 câu)](#mock-chuong-20-15-cau)
# - [Mini-Mock Tổng Hợp](#mini-mock-tong-hop)
# - [Mock Tổng Hợp 1 (40 câu)](#mock-tong-hop-1-40-cau)
# - [Mock Tổng Hợp 2 (40 câu)](#mock-tong-hop-2-40-cau)
# - [Mock Tổng Hợp 3 (40 câu)](#mock-tong-hop-3-40-cau)
# - [Mock Tổng Hợp 4 (40 câu)](#mock-tong-hop-4-40-cau)
# - [Mock Tổng Hợp 5 (40 câu)](#mock-tong-hop-5-40-cau)

# %%
# Auto-set language metadata for all code cells in this notebook.
# Save notebook before running; it will rewrite the .ipynb file on disk.

import json
import re
from pathlib import Path

NB_PATH = Path("c_cpp_materials.ipynb")  # change if needed
MODE = "detect"  # "detect" -> set C/C++/Python; "auto" -> clear per-cell language metadata


def detect_language(src: str):
    lines = [l for l in src.splitlines() if l.strip()]
    if not lines:
        return None

    first = lines[0].lstrip()
    if first.startswith("%%"):
        tag = first[2:].split()[0].lower()
        if tag in ("cpp", "c++"):
            return "cpp"
        if tag == "c":
            return "c"
        if tag in ("python", "py"):
            return "python"

    text = "\n".join(lines)
    lower = text.lower()

    score = {"python": 0, "cpp": 0, "c": 0}

    py_tokens = [
        "import ", "from ", "def ", "print(", "lambda ",
        "none", "true", "false", "try:", "except", "with ",
        "yield ", "async ", "await ", "elif ", "self",
    ]
    cpp_tokens = [
        "#include", "std::", "using namespace std", "cout", "cin",
        "vector<", "string", "new ", "delete", "template<",
        "namespace ", "nullptr", "auto ", "::",
    ]
    c_tokens = [
        "#include", "printf(", "scanf(", "malloc(", "free(",
        "sizeof", "int main", "char *", "struct ", "typedef ",
        "enum ", "fopen(", "fgets(", "puts(", "gets(",
    ]

    for t in py_tokens:
        if t in lower or t in text:
            score["python"] += 2
    for t in cpp_tokens:
        if t in lower or t in text:
            score["cpp"] += 2
    for t in c_tokens:
        if t in lower or t in text:
            score["c"] += 2

    if "iostream" in lower or "std::" in lower or "using namespace std" in lower:
        score["cpp"] += 3
    if "stdio.h" in lower or "stdlib.h" in lower:
        score["c"] += 3

    if score["python"] > score["cpp"] and score["python"] > score["c"]:
        return "python"
    if score["cpp"] > score["c"]:
        return "cpp"
    if score["c"] > 0:
        return "c"

    if re.search(r"^\s*(def|class|for|while|if|elif|else|try|with)\b.*:\s*$", text, re.M):
        return "python"

    return None


nb = json.loads(NB_PATH.read_text(encoding="utf-8"))

updated = 0
cleared = 0

for cell in nb.get("cells", []):
    if cell.get("cell_type") != "code":
        continue
    src = "".join(cell.get("source", []))
    md = cell.setdefault("metadata", {})

    if MODE == "auto":
        if "language" in md:
            md.pop("language", None)
            cleared += 1
        vs = md.get("vscode")
        if isinstance(vs, dict) and "languageId" in vs:
            vs.pop("languageId", None)
            cleared += 1
            if not vs:
                md.pop("vscode", None)
        continue

    lang = detect_language(src)
    if lang is None:
        if "language" in md:
            md.pop("language", None)
            cleared += 1
        vs = md.get("vscode")
        if isinstance(vs, dict) and "languageId" in vs:
            vs.pop("languageId", None)
            cleared += 1
            if not vs:
                md.pop("vscode", None)
        continue

    display, lang_id = {
        "cpp": ("C++", "cpp"),
        "c": ("C", "c"),
        "python": ("python", "python"),
    }[lang]

    if md.get("language") != display:
        md["language"] = display
        updated += 1

    vs = md.get("vscode")
    if not isinstance(vs, dict):
        vs = {}
    if vs.get("languageId") != lang_id:
        vs["languageId"] = lang_id
        md["vscode"] = vs
        updated += 1

NB_PATH.write_text(json.dumps(nb, ensure_ascii=False, indent=1), encoding="utf-8")
print(f"Updated: {updated}, Cleared: {cleared}")
# Out:
# Updated: 0, Cleared: 0

# %% [markdown]
# <a id="ch1"></a>
# ## Chương 1. Cơ bản: cấu trúc chương trình và xuất dữ liệu
#
# **Prerequisites**
# - Không yêu cầu.
#
# **Learning outcomes**
# - Nhận biết được “khung” tối thiểu của một chương trình C/C++ khi làm bài thi (`#include`, `main`, `{}`, `;`).
# - Biết dùng comment để chú thích và dùng `printf` để in ra màn hình.
# - Hiểu các escape sequence cơ bản trong chuỗi: `\n`, `\t`, `\"`.
#
# ### Giải thích
#
# #### 1) “Khung” tối thiểu của chương trình (khi viết file .c/.cpp)
# Khi làm bài thi hoặc viết chương trình dưới dạng file, bạn thường gặp dạng chuẩn sau:
#
# ```c
# #include <stdio.h>
#
# int main(void) {
#     printf("Hello!\n");
#     return 0;
# }
# ```
#
# Giải thích nhanh từng phần:
# - `#include <stdio.h>`: nạp thư viện I/O chuẩn để dùng `printf`.
# - `int main(void)`: hàm **bắt đầu chương trình**. `void` nghĩa là không nhận tham số.
# - `{ ... }`: **khối lệnh**. Các câu lệnh nằm trong khối sẽ được thực thi theo thứ tự.
# - `;`: kết thúc **một câu lệnh** trong C.
#
# > Ghi chú cho notebook (xcpp17/xeus-cling): trong notebook, bạn có thể chạy trực tiếp các câu lệnh như `printf(...)` mà **không cần** `main`. Để vừa “đúng form đề thi” vừa chạy được, các ví dụ dưới đây sẽ **comment** dòng `int main...{` và `}` (và thường comment cả `return 0;`).
#
# #### 2) In ra màn hình với `printf`
# - `printf` dùng để in ra màn hình.
# - Ở Chương 1, bạn chỉ cần in **chuỗi** và dùng `\n` để xuống dòng.
#
# Bẫy hay gặp (đề thi rất hay hỏi):
# - Quên dấu `;` ở cuối câu lệnh → lỗi biên dịch.
# - Quên `#include <stdio.h>` → không dùng được `printf` (hoặc bị warning).
# - Nhầm `'A'` (ký tự) với `"A"` (chuỗi).
#
# #### 3) Escape sequence trong chuỗi
# Escape sequence là “ký tự đặc biệt” bắt đầu bằng `\` trong chuỗi:
# - `\n`: xuống dòng.
# - `\t`: tab.
# - `\"`: in dấu nháy kép `"` bên trong chuỗi.
#
# #### 4) Comment
# - `// comment một dòng`.
# - `/* comment nhiều dòng */`.
#
# Bẫy: quên đóng `*/` sẽ khiến phần sau bị “nuốt” thành comment.
#
# ### Ví dụ
#
# #### Ví dụ 1 — Hello + khung chương trình
# - Mục tiêu: thấy “form đề thi” có `main`, nhưng vẫn chạy được trong notebook.
# - Kết quả kỳ vọng: in ra 2 dòng.
# - Bẫy cần nhớ: `\n` để xuống dòng, và dấu `;` ở cuối câu lệnh.

# %%
#include <stdio.h>

// Trong file .c/.cpp khi làm bài thi, chương trình thường bắt đầu ở main:
//int main(void) {
{
    // Mọi câu lệnh trong C kết thúc bằng dấu ';'
    printf("Hello C!\n");

    // In thêm 1 dòng để thấy tác dụng của '\n' (xuống dòng)
    printf("Dong 2: Chay trong notebook (khong can main).\n");

    // Trong file .c/.cpp: return 0; báo kết thúc thành công.
    // Trong notebook: 'return' không đứng ngoài hàm, nên ta comment.
    //return 0;
}
//} // Kết thúc main

# %% [markdown]
# #### Ví dụ 2 — Escape sequence: \n, \t, \"
# - Mục tiêu: nhìn output để hiểu ngay `\n` (xuống dòng), `\t` (tab), `\"` (in dấu ").
# - Kết quả kỳ vọng: các cột thẳng hàng bằng tab, và in được dấu nháy kép.

# %%
#include <stdio.h>

int main(void) {
    printf("Cot 1\tCot 2\tCot 3\n");
    printf("1\t2\t3\n\n");

    printf("Dong 1\nDong 2\n\n");

    // Muốn in dấu " bên trong chuỗi, ta dùng escape \"
    printf("In dau nhay kep: \"Hello\"\n");
    return 0;
}

# %% [markdown]
# #### Ví dụ 3 — Comment và các lỗi cú pháp hay gặp
# - Mục tiêu: phân biệt `//` và `/*...*/`, và nhận diện các lỗi “nhìn là biết” trong bài thi.
# - Lưu ý: các dòng sai đã được comment để cell vẫn chạy.

# %%
#include <stdio.h>

int main(void) {
    // 1) Comment một dòng bằng //
    // printf("Dong nay bi comment nen khong in ra\n");

    // 2) Comment nhiều dòng dùng cú pháp: /* ... */
    // Ví dụ dưới đây là một comment nhiều dòng hợp lệ:
    /*
       Day la comment nhieu dong.
       Dung khi ban muon ghi chu nhieu dong lien tiep.
    */

    printf("Comment chi la ghi chu, chuong trinh van chay binh thuong.\n");

    // Một số lỗi cú pháp rất hay gặp (đã comment để tránh lỗi):
    //printf("Quen dau cham phay")  // <- thiếu ' ;' sẽ lỗi biên dịch
    //prntf("Sai ten ham\n");      // <- viết sai tên hàm printf
    return 0;
}

# %% [markdown]
# ### Luyện tập
# 1. Sửa chương trình để in thêm tên của bạn ở dòng thứ hai.
# 2. Thêm comment giải thích chức năng của từng dòng.
# 3. Nếu bỏ `return 0;` thì có vấn đề gì không?
#
# <details>
# <summary>Solution</summary>
#
# Gợi ý:
# - Dùng thêm một `printf("Ten: ...\n");`.
# - Comment có thể là `//` hoặc `/* ... */`.
# - Trong C chuẩn, `main` nên trả về `int`. Nếu bỏ `return 0;` thì một số trình biên dịch vẫn chấp nhận nhưng không khuyến khích.
# </details>

# %% [markdown]
# ### Lỗi thường gặp
# - Quên `;` sau câu lệnh.
# - Thiếu `#include <stdio.h>` nên không dùng được `printf`.
# - Viết sai chữ hoa/thường trong `main`.
#
# ### Tóm tắt
# - `main` là điểm bắt đầu của chương trình.
# - `printf` dùng để xuất dữ liệu.
# - Comment giúp giải thích code.
#
# ### Checkpoint quiz
# 1. Hàm nào là điểm bắt đầu chương trình C?
# 2. Comment một dòng bắt đầu bằng ký hiệu nào?
# 3. `#include <stdio.h>` dùng để làm gì?
#
# <details>
# <summary>Đáp án</summary>
#
# 1. `main`.
# 2. `//`.
# 3. Nạp thư viện chuẩn chứa khai báo `printf` và các hàm I/O.
# </details>

# %% [markdown]
# <a id="ch2"></a>
# ## Chương 2. Biến, kiểu dữ liệu, hằng, sizeof, định dạng in
#
# **Prerequisites**
# - Chương 1.
#
# **Learning outcomes**
# - Khai báo và khởi tạo biến cơ bản (`int`, `double`, `char`).
# - Hiểu chia nguyên vs chia thực và biết ép kiểu để ra kết quả mong muốn.
# - Biết dùng `const` để tạo hằng và dùng `sizeof` để biết kích thước theo byte.
# - In đúng định dạng với `printf` (bẫy rất hay gặp trong đề).
#
# ### Giải thích
#
# #### 1) Biến là gì? (và vì sao phải khởi tạo)
# - **Biến** là “một vùng nhớ có tên” dùng để lưu giá trị.
# - Bạn nên **khởi tạo** biến ngay khi khai báo để tránh “giá trị rác”.
#
# Ví dụ:
# - `int age = 20;` (đã khởi tạo)
# - `int x;` rồi dùng `x` ngay (đề thi hay gài) → giá trị **không xác định**.
#
# #### 2) Kiểu dữ liệu cơ bản và ý nghĩa
# - `int`: số nguyên.
# - `double` (hoặc `float`): số thực.
# - `char`: ký tự, nhưng thực chất cũng là **một số nguyên nhỏ** (mã ASCII).
#
# Bẫy hay gặp:
# - Chia nguyên: `5/2` cho ra `2` (không phải `2.5`).
# - In sai định dạng `printf` (ví dụ dùng `%d` cho `double`) → kết quả sai/khó đoán.
#
# #### 3) Hằng với `const`
# - `const` tạo ra biến “không đổi” sau khi khởi tạo.
# - Nếu cố gắng gán lại sẽ bị lỗi biên dịch.
#
# #### 4) `sizeof` trả về gì?
# - `sizeof(T)` cho biết **số byte** của kiểu `T`.
# - Giá trị trả về có kiểu `size_t` (thường là số nguyên không âm).
# - Khi in `sizeof`, dùng `%zu` (đúng chuẩn).
#
# #### 5) `printf` format cơ bản (mức thi)
# Một số format hay dùng:
# - `%d`: `int`
# - `%f`: số thực (`double` khi truyền vào `printf`)
# - `%.2f`: in số thực với 2 chữ số sau dấu phẩy
# - `%c`: `char`
# - `%zu`: `size_t` (kết quả của `sizeof`)
#
# ### Ví dụ
#
# #### Ví dụ 1 — Khai báo biến + in đúng định dạng
# - Mục tiêu: nhìn format `printf` và hiểu “in cái gì thì dùng % gì”.
# - Bẫy cần nhớ: `%d` ≠ `%f` ≠ `%c`.

# %%
#include <stdio.h>

// Nếu viết file .c/.cpp, các dòng dưới thường nằm trong main:
//int main(void) {
{
    int age = 20;
    double pi = 3.14159;
    char grade = 'A';
    const int YEAR = 2026;

    printf("Age = %d\n", age);
    printf("Pi = %.2f\n", pi);
    printf("Grade = %c\n", grade);
    printf("YEAR = %d\n", YEAR);

    // Sai format (đã comment): dùng %d cho double có thể in ra giá trị rác.
    //printf("Pi (sai format) = %d\n", pi);
}
//}

# %% [markdown]
# #### Ví dụ 2 — Chia nguyên vs chia thực (bẫy kinh điển)
# - Mục tiêu: dự đoán đúng kết quả của `5/2` và biết cách ép kiểu để ra `2.5`.
# - Kết quả kỳ vọng: dòng đầu ra `2`, các dòng sau ra `2.500000`.

# %%
#include <stdio.h>

int main(void) {
    int a = 5;
    int b = 2;

    // a và b đều là int => chia nguyên
    printf("a/b (int) = %d\n", a / b);

    // Ép kiểu để phép chia trở thành chia thực
    printf("(double)a/b = %f\n", (double)a / b);
    printf("a/(double)b = %f\n", a / (double)b);
    return 0;
}

# %% [markdown]
# #### Ví dụ 3 — `char` là ký tự nhưng cũng là số (ASCII)
# - Mục tiêu: thấy rõ sự khác nhau giữa `%c` và `%d` khi in một `char`.
# - Kết quả kỳ vọng: in `A` và in mã ASCII (65).

# %%
#include <stdio.h>

int main(void) {
    char ch = 'A';

    printf("ch as char = %c\n", ch);
    printf("ch as ASCII = %d\n", (int)ch);
    return 0;
}

# %% [markdown]
# #### Ví dụ 4 — `sizeof` và cách in an toàn với `%zu`
# - Mục tiêu: biết `sizeof` trả về số byte, và dùng `%zu` để in đúng.
# - Ghi nhớ: `sizeof` không phải hàm; nó là toán tử.

# %%
#include <stdio.h>

int main(void) {
    printf("sizeof(char)   = %zu byte\n", sizeof(char));
    printf("sizeof(int)    = %zu bytes\n", sizeof(int));
    printf("sizeof(double) = %zu bytes\n", sizeof(double));
    return 0;
}

# %% [markdown]
# ### Luyện tập
# 1. Khai báo hai biến `double` là chiều dài và chiều rộng, tính diện tích hình chữ nhật.
# 2. Khai báo một ký tự và in ra mã ASCII của nó (dùng `%d`).
# 3. Viết hằng `PI = 3.14` và dùng để tính chu vi hình tròn bán kính 5.
#
# <details>
# <summary>Solution</summary>
#
# Gợi ý:
# - Diện tích hình chữ nhật: `area = length * width`.
# - Ép kiểu `int` khi in mã ASCII: `printf("%d", (int)ch);`.
# - Chu vi: `2 * PI * r`.
# </details>

# %% [markdown]
# ### Lỗi thường gặp
# - Dùng sai định dạng `printf` (ví dụ `%d` cho `double`).
# - Quên khởi tạo biến trước khi dùng.
# - Nhầm `float` với `double` trong tính toán.
#
# ### Tóm tắt
# - Biến cần khai báo kiểu trước khi dùng.
# - `const` tạo hằng không đổi.
# - `sizeof` cho biết kích thước tính theo byte.
#
# ### Checkpoint quiz
# 1. Kiểu nào phù hợp lưu số thực chính xác cao hơn: `float` hay `double`?
# 2. `sizeof(int)` trả về đơn vị gì?
# 3. Ký tự định dạng nào dùng cho `char` trong `printf`?
#
# <details>
# <summary>Đáp án</summary>
#
# 1. `double`.
# 2. Byte.
# 3. `%c`.
# </details>

# %% [markdown]
# <a id="ch3"></a>
# ## Chương 3. Toán tử và biểu thức
#
# **Prerequisites**
# - Chương 2.
#
# **Learning outcomes**
# - Dự đoán đúng kết quả biểu thức số học (đặc biệt: **chia nguyên** và `%`).
# - Phân biệt rõ `=` (gán) và `==` (so sánh) trong điều kiện.
# - Hiểu `&&`, `||`, `!` và cơ chế **short-circuit** (dừng sớm) để tránh lỗi.
# - Dùng đúng toán tử `?:` và phân biệt `++i` với `i++` trong biểu thức.
# - Biết các bẫy phổ biến trong đề: chia nguyên, nhầm toán tử, viết biểu thức gây “không xác định”.
#
# ### Giải thích
#
# #### 1) Toán tử số học: `+ - * / %`
# - `+ - * /`: phép toán cơ bản.
# - `/` có 2 “kiểu chia” (đề thi rất hay hỏi):
#   - Nếu **hai toán hạng đều là `int`** → **chia nguyên** (bỏ phần thập phân).
#   - Nếu **có ít nhất 1 toán hạng là số thực** (`float/double`) → **chia thực**.
# - `%` (modulo/phần dư) chỉ dùng cho **số nguyên**.
#
# Bẫy kinh điển:
# - `7/2` cho ra `3` (không phải `3.5`).
# - `7%2` cho ra `1`.
#
# #### 2) `=` (gán) khác `==` (so sánh)
# - `=`: **thay đổi biến** và biểu thức gán cũng có **giá trị** (giá trị vừa gán).
# - `==`: **so sánh** và cho ra đúng/sai.
#
# Bẫy rất hay gặp:
# - `if (x = 0)` là **gán**, và điều kiện sẽ thành **false** (vì gán 0).
# - `if (x = 5)` là **gán**, và điều kiện sẽ thành **true** (vì gán 5 ≠ 0).
#
# #### 3) Toán tử logic `&& || !` và short-circuit
# - `A && B`: nếu `A` **false** thì **không cần** kiểm tra `B` nữa. (And - Kết quả `true` chỉ khi cả `A` và `B` đều `true`.)
# - `A || B`: nếu `A` **true** thì **không cần** kiểm tra `B` nữa. (Or - Chỉ `false` khi cả `A` và `B` đều `false`.)
#
# - `!A`: đảo giá trị logic của `A` (NOT) — nếu `A` true thì `!A` false, nếu `A` false thì `!A` true
#
# Ứng dụng rất thực tế (dạng đề hay ra):
# - Tránh chia cho 0: `a != 0 && (b/a > 1)`.
#
# #### 4) Toán tử điều kiện `?:`
#
# - `condition ? expr_if_true : expr_if_false`
#
# Dạng: `cond ? a : b`
# - Nếu `cond` đúng → lấy `a`.
# - Nếu `cond` sai → lấy `b`.
#
# Hay dùng để gán nhanh:
# - `max = (a > b) ? a : b;`
#
# Bẫy: biểu thức dài nên thêm ngoặc để dễ đọc và tránh nhầm ưu tiên.
#
# #### 5) `++i` vs `i++` và bẫy “không xác định”
# - `++i` (tiền tố): **tăng trước**, rồi mới dùng.
# - `i++` (hậu tố): **dùng trước**, rồi mới tăng.
#
# Bẫy mức thi (đừng viết):
# - `i = i++;` hoặc `i++ + ++i` → kết quả **không đáng tin** (không nên suy luận).
#
# #### 6) Thứ tự ưu tiên toán tử (cần nhớ mức tối thiểu)
# - `* / %` ưu tiên hơn `+ -`.
# - So sánh (`==`, `!=`, `<`, ...) thường được nhóm trước logic `&&`, `||`.
# - Gán (`=`) thường gần cuối.
#
# > Mẹo làm bài thi: nếu thấy “lăn tăn” khi đọc biểu thức, **tự thêm ngoặc** khi phân tích.
#
# ### Ví dụ
#
# #### Ví dụ 1 — Chia nguyên vs chia thực + `%`
# - Mục tiêu: chốt bẫy `7/2` và nhớ `%` chỉ dùng cho số nguyên.
# - Kết quả kỳ vọng: `7/2 = 3`, `7%2 = 1`, còn chia thực ra `3.500000`.

# %%
#include <stdio.h>

int main(void) {
    int a = 7;
    int b = 2;

    // 1) Chia nguyên: cả a và b là int => bỏ phần thập phân
    printf("7 / 2 = %d\n", a / b);

    // 2) Lấy dư: chỉ áp dụng cho số nguyên
    printf("7 %% 2 = %d\n", a % b);

    // 3) Chia thực: chỉ cần 1 toán hạng là số thực
    printf("7 / 2.0 = %f\n", a / 2.0);
    printf("(double)7 / 2 = %f\n", (double)a / b);
    return 0;
}

# %% [markdown]
# #### Ví dụ 2 — Bẫy `=` vs `==` trong `if`
# - Mục tiêu: nhìn output để nhớ: `=` là gán (làm đổi biến), `==` là so sánh.
# - Lưu ý: dòng `if (x = 5)` thường bị compiler cảnh báo, nhưng đề thi vẫn hay hỏi logic.

# %%
#include <stdio.h>

int main(void) {
    int x = 0;

    if (x == 0) {
        printf("(1) x == 0 la DUNG\n");
    }

    x = 123;

    // Bẫy: đây là gán, không phải so sánh.
    if (x = 0) {
        printf("(2) Se KHONG bao gio vao day\n");
    } else {
        // Sau câu lệnh trên, x đã bị gán thành 0.
        printf("(2) if(x = 0) la SAI, x hien tai = %d\n", x);
    }

    // Bẫy khác: gán 5 (khác 0) => điều kiện true
    if (x = 5) {
        printf("(3) if(x = 5) la DUNG, x hien tai = %d\n", x);
    }
    return 0;
}

# %% [markdown]
# #### Ví dụ 3 — Short-circuit để tránh chia cho 0
# - Mục tiêu: thấy rõ `&&` dừng sớm giúp tránh lỗi (không thực hiện phép chia khi `a==0`).
# - Bẫy: đảo điều kiện thành `(b/a > 1) && a != 0` có thể gây lỗi chia cho 0.

# %%
#include <stdio.h>

int main(void) {
    int a = 0;
    int b = 10;

    if (a != 0 && (b / a) > 1) {
        printf("Se khong vao day\n");
    } else {
        printf("An toan: a == 0 nen khong chia\n");
    }

    a = 2;
    if (a != 0 && (b / a) > 1) {
        printf("a = 2 => b/a = %d > 1\n", b / a);
    }

    // DANG NGUY HIEM (comment): chia cho 0 neu a==0
    //if ((b / a) > 1 && a != 0) {
    //    printf("...\n");
    //}
    return 0;
}

# %% [markdown]
# #### Ví dụ 4 — `i++` vs `++i` (và tránh biểu thức không xác định)
# - Mục tiêu: dự đoán đúng giá trị trước/sau khi tăng.
# - Nhắc lại: đừng viết các biểu thức kiểu `i++ + ++i` trong bài thi.

# %%
#include <stdio.h>

int main(void) {
    int x = 10;

    int y = x++; // y nhận giá trị cũ (10), sau đó x mới tăng thành 11
    int z = ++x; // x tăng trước thành 12, rồi z nhận 12

    printf("Sau y = x++;  y=%d\n", y);
    printf("Sau z = ++x;  x=%d z=%d\n", x, z);

    // Ví dụ 'không nên làm' (kết quả không đáng tin):
    //int t = x++ + ++x;
    //printf("t=%d\n", t);
    return 0;
}

# %% [markdown]
# ### Luyện tập
# 1. Viết lại câu lệnh `if (a > b) max = a; else max = b;` bằng toán tử `?:`.
# 2. Dự đoán giá trị của `i`, `j`, `k` với: `int i=3; int j=i++; int k=++i;`.
# 3. Tại sao `x = x++;` không làm `x` thay đổi?
#
# <details>
# <summary>Solution</summary>
#
# 1. `max = (a > b) ? a : b;`
# 2. `j=3`, sau đó `i=4`; `k=5`, cuối cùng `i=5`.
# 3. `x++` trả về giá trị cũ, sau đó tăng; phép gán lại ghi đè, nên `x` không đổi.
# </details>

# %% [markdown]
# ### Lỗi thường gặp
# - Nhầm `=` (gán) với `==` (so sánh).
# - Chia nguyên khi muốn chia thực.
# - Hiểu sai `i++` và `++i`.
#
# ### Tóm tắt
# - Toán tử quyết định cách tính và thứ tự đánh giá biểu thức.
# - `?:` là dạng rút gọn của `if/else`.
# - `++i` và `i++` khác nhau trong biểu thức.
#
# ### Checkpoint quiz
# 1. `7 / 2` cho kết quả gì nếu cả hai là `int`?
# 2. Toán tử nào dùng để “khác nhau”?
# 3. Với `int i=1; int a=i++; int b=++i;` thì `a` và `b` là bao nhiêu?
#
# <details>
# <summary>Đáp án</summary>
#
# 1. `3`.
# 2. `!=`.
# 3. `a=1`, `b=3`.
# </details>

# %% [markdown]
# <a id="ch4"></a>
# ## Chương 4. Điều khiển luồng
#
# **Prerequisites**
# - Chương 3.
#
# **Learning outcomes**
# - Đọc/viết đúng cấu trúc `if/else if/else` và tránh bẫy “dangling else”.
# - Dùng `switch/case` đúng cách và nhận biết bẫy **thiếu `break`** (fall-through).
# - Phân biệt `for/while/do-while` (đặc biệt: `do-while` chạy ít nhất 1 lần).
# - Dự đoán output khi có `break/continue`.
#
# ### Giải thích
#
# #### 1) Điều kiện trong C/C++: 0 và khác 0
# Trong C/C++:
# - `0` được hiểu là **false**.
# - Bất kỳ giá trị khác `0` được hiểu là **true**.
#
# Vì vậy `if (x)` nghĩa là “nếu x khác 0”.
#
# Bẫy: `if (x = 5)` là **gán**, và vì 5 ≠ 0 nên luôn true.
#
# #### 2) `if / else if / else` và bẫy “else gắn với if gần nhất”
# Nếu không dùng `{}` thì `else` sẽ gắn với `if` gần nhất (đề thi hay gài).
#
# Mẹo an toàn khi làm bài:
# - Nếu trong `if` có nhiều hơn 1 câu lệnh, hãy luôn dùng `{}`.
#
# #### 3) `switch/case`: fall-through và `break`
# - `switch` phù hợp khi so sánh một biến với **nhiều giá trị rời rạc**.
# - Nếu thiếu `break`, chương trình sẽ **rơi qua** (fall-through) sang `case` tiếp theo.
#
# #### 4) Vòng lặp `for / while / do-while`
# - `for`: tiện khi biết trước số lần lặp.
# - `while`: lặp khi còn thỏa điều kiện.
# - `do-while`: **chạy trước, kiểm tra sau** → luôn chạy ít nhất 1 lần.
#
# Bẫy rất hay gặp: off-by-one (`i < n` khác `i <= n`).
#
# #### 5) `break` và `continue`
# - `break`: thoát khỏi **vòng lặp hiện tại** (hoặc thoát `switch`).
# - `continue`: bỏ qua phần còn lại của lần lặp hiện tại và sang lần lặp tiếp theo.
#
# > Lưu ý: trong vòng lặp lồng nhau, `break` chỉ thoát **1 mức**.
#
# ### Ví dụ
#
# #### Ví dụ 1 — `switch` thiếu `break` (fall-through)
# - Mục tiêu: nhìn output để “khắc” vào đầu: thiếu `break` sẽ chạy tiếp case sau.

# %%
#include <stdio.h>

int main(void) {
    int day = 2;

    printf("Switch thieu break:\n");
    switch (day) {
        case 2:
            printf("Thu 2\n");
            // THIEU break => rơi qua case 3
        case 3:
            printf("Thu 3\n");
            break;
        default:
            printf("Khac\n");
            break;
    }

    printf("\nSwitch day du break:\n");
    switch (day) {
        case 2:
            printf("Thu 2\n");
            break;
        case 3:
            printf("Thu 3\n");
            break;
        default:
            printf("Khac\n");
            break;
    }
    return 0;
}

# %% [markdown]
# #### Ví dụ 2 — `while` vs `do-while`
# - Mục tiêu: thấy `do-while` chạy ít nhất 1 lần, dù điều kiện ban đầu sai.

# %%
#include <stdio.h>

int main(void) {
    int i = 0;

    printf("while (i < 0):\n");
    while (i < 0) {
        printf("i=%d\n", i);
        i++;
    }
    printf("Ket thuc while (khong in gi vi dieu kien sai ngay tu dau)\n\n");

    i = 0;
    printf("do {..} while (i < 0):\n");
    do {
        printf("i=%d\n", i);
        i++;
    } while (i < 0);
    printf("Ket thuc do-while (van chay 1 lan)\n");
    return 0;
}

# %% [markdown]
# #### Ví dụ 3 — Off-by-one trong `for` (`i < n` vs `i <= n`)
# - Mục tiêu: nhìn số lần lặp để tránh lỗi vượt biên mảng.
# - Gợi ý: với mảng `a[n]`, chỉ số hợp lệ là `0..n-1`.

# %%
#include <stdio.h>

int main(void) {
    int n = 5;

    printf("for (i=0; i<n; i++): ");
    for (int i = 0; i < n; i++) {
        printf("%d ", i);
    }
    printf("\n");

    printf("for (i=0; i<=n; i++): ");
    for (int i = 0; i <= n; i++) {
        printf("%d ", i);
    }
    printf("\n");

    // Nếu i dùng làm chỉ số mảng a[n], vòng i<=n sẽ cố truy cập a[n] (SAI).
    return 0;
}

# %% [markdown]
# #### Ví dụ 4 — `break` và `continue` trong vòng lặp
# - Mục tiêu: dự đoán output: `continue` bỏ qua, `break` thoát sớm.

# %%
#include <stdio.h>

int main(void) {
    for (int i = 1; i <= 10; i++;) {
        if (i == 5) {
            // Bỏ qua số 5
            continue;
        }
        if (i == 8) {
            // Dừng vòng lặp khi gặp 8
            break;
        }
        printf("%d ", i);
    }
    printf("\n");
    return 0;
}

# %% [markdown]
# ### Luyện tập
# 1. Tính tổng từ 1 đến 100 bằng vòng lặp `for`.
# 2. Viết `switch` để in tên tháng khi biết số tháng 1–12.
# 3. Viết vòng lặp `while` để đếm ngược từ 5 về 1.
#
# <details>
# <summary>Solution</summary>
#
# Gợi ý:
# - Dùng biến tích lũy `sum`.
# - `switch` cần có `break` cho mỗi `case`.
# - Vòng lặp `while (n > 0) { ...; n--; }`.
# </details>

# %%
#include <stdio.h>

int main(void) {
  int sum = 0;
  for (int i=0; i<=100;) {
    sum = sum + i;
    i++;
    }
    printf("sum = %d\n", sum);
    return 0;
}

# %%
#include <stdio.h>

int main(void) {
  int month;
  printf("Month is: ");
  scanf("%d", &month);

  switch(month){
    case 1: printf("January"); break;
    case 2: printf("February"); break;
    //...
  }
    return 0;
}

# %%
#include <stdio.h>

int main(void) {
  int i = 5;
  while (i > 0) {
    printf ("%d ", i);
    i--;
  }
    return 0;
}

# %% [markdown]
# ### Lỗi thường gặp
# - Quên `break` trong `switch` dẫn đến rơi qua nhánh.
# - Điều kiện vòng lặp sai gây lặp vô hạn.
# - Dùng `=` thay vì `==` trong điều kiện.
#
# ### Tóm tắt
# - `if/else` rẽ nhánh theo điều kiện.
# - `switch` phù hợp khi có nhiều giá trị rời rạc.
# - Vòng lặp giúp lặp lại công việc.
#
# ### Checkpoint quiz
# 1. Khi nào nên dùng `switch` thay vì nhiều `if/else`?
# 2. `do-while` khác `while` ở điểm nào?
# 3. Điều gì xảy ra nếu thiếu `break` trong `switch`?
#
# <details>
# <summary>Đáp án</summary>
#
# 1. Khi so sánh một biến với nhiều giá trị rời rạc.
# 2. `do-while` luôn chạy ít nhất 1 lần.
# 3. Chương trình chạy tiếp các `case` sau (rơi qua nhánh).
# </details>

# %% [markdown]
# <a id="ch5"></a>
# ## Chương 5. Hàm và phạm vi
#
# **Prerequisites**
# - Chương 4.
#
# **Learning outcomes**
# - Hiểu sự khác nhau giữa **prototype (khai báo)** và **definition (định nghĩa)** hàm.
# - Nhận biết pass-by-value: sửa tham số trong hàm **không** làm đổi biến bên ngoài.
# - Biết phạm vi (scope) và vòng đời (lifetime) của biến cục bộ, global, và `static` cục bộ.
# - Viết được recursion (đệ quy) cơ bản (factorial) và biết cần “điểm dừng”.
#
# ### Giải thích
#
# #### 1) Prototype vs định nghĩa hàm
# - **Prototype** (khai báo): cho compiler biết “hàm tên gì, nhận gì, trả gì” để có thể gọi.
# - **Định nghĩa** (definition): phần thân `{ ... }` thực sự làm công việc.
#
# Vì sao cần prototype?
# - Trong C/C++, nếu bạn gọi hàm trước khi compiler thấy định nghĩa, bạn phải có prototype.
#
# #### 2) Pass-by-value (truyền tham trị)
# Mặc định trong C:
# - Tham số trong hàm là **bản sao**.
# - Sửa `a`, `b` trong hàm **không** làm đổi biến gốc ngoài hàm.
#
# > Muốn đổi biến gốc, ta cần truyền “địa chỉ” (pointer) hoặc (trong C++) dùng reference.
# > Pointer sẽ học kỹ ở Chương 7, reference ở Chương 14.
#
# #### 3) Scope & lifetime
# - Biến cục bộ: chỉ sống trong block `{ ... }`.
# - Biến global: sống suốt chương trình.
# - `static` cục bộ: scope như biến cục bộ nhưng **giữ giá trị** qua nhiều lần gọi hàm.
#
# Bẫy: trả về địa chỉ của biến cục bộ (sẽ gặp lại khi học con trỏ/malloc).
#
# #### 4) Recursion (đệ quy) mức cơ bản
# - Hàm gọi lại chính nó.
# - Bắt buộc có **base case** (điểm dừng) để không gọi vô hạn.
#
# ### Ví dụ
#
# #### Ví dụ 1 — Prototype giúp gọi hàm trước khi định nghĩa
# - Mục tiêu: thấy vì sao cần prototype nếu muốn đặt định nghĩa hàm ở phía dưới.
# - Kết quả kỳ vọng: in ra max của 2 số.

# %%
#include <stdio.h>

// Prototype: compiler biết chữ ký của hàm trước khi gặp định nghĩa
int max2(int a, int b);

int main(void) {
    printf("max2(3, 5) = %d\n", max2(3, 5));
    return 0;
}

// Notebook tip: để chạy lại cell không bị lỗi "redefinition",
// ta chỉ định nghĩa hàm 1 lần bằng macro guard.
#ifndef CH5_EX1_MAX2_DEFINED
#define CH5_EX1_MAX2_DEFINED
int max2(int a, int b) {
    return (a > b) ? a : b;
}
#endif

# %% [markdown]
# #### Ví dụ 2 — Swap “không đổi” (pass-by-value) vs swap đúng bằng pointer
# - Mục tiêu: bẫy thi kinh điển: đổi trong hàm nhưng ngoài không đổi.
# - Gợi mở: pointer là “biến lưu địa chỉ”. `&x` là địa chỉ của x, `*p` là giá trị tại địa chỉ p.

# %%
#include <stdio.h>

void swap_by_value(int a, int b);
void swap_by_ptr(int* a, int* b);

int main(void) {
    int x = 1;
    int y = 2;

    printf("Ban dau: x=%d y=%d\n", x, y);

    swap_by_value(x, y);
    printf("Sau swap_by_value: x=%d y=%d (KHONG DOI)\n", x, y);

    swap_by_ptr(&x, &y);
    printf("Sau swap_by_ptr:   x=%d y=%d (DA DOI)\n", x, y);
    return 0;
}

#ifndef CH5_EX2_SWAP_DEFINED
#define CH5_EX2_SWAP_DEFINED
void swap_by_value(int a, int b) {
    int tmp = a;
    a = b;
    b = tmp;
    // a,b chỉ là bản sao => không ảnh hưởng biến gốc
}

void swap_by_ptr(int* a, int* b) {
    // a,b là con trỏ: a trỏ tới biến x, b trỏ tới biến y
    int tmp = *a; // lấy GIÁ TRỊ tại địa chỉ a
    *a = *b;
    *b = tmp;
}
#endif

# %%
#include <stdio.h>

int swap_by_value(int a, int b);

int main()
{
    int x = 1;
    int y = 2;

    printf("Ban dau: x=%d y=%d\n", x, y);

    swap_by_value(x, y);
    printf("Sau swap_by_value: x=%d y=%d \n", swap_by_value(x, y));
}

#ifndef CH5_EX2_SWAP_DEFINED
#define CH5_EX2_SWAP_DEFINED
int swap_by_value(int a, int b) {
  return b, a; //trả về biểu thức cuối (a)
}
#endif

# %% [markdown]
# #### Ví dụ 3 — `static` cục bộ: nhớ giá trị qua nhiều lần gọi
# - Mục tiêu: hiểu “scope cục bộ nhưng lifetime dài”.

# %%
#include <stdio.h>

int next_counter(void);

int main(void) {
    printf("%d\n", next_counter());
    printf("%d\n", next_counter());
    printf("%d\n", next_counter());
    return 0;
}

#ifndef CH5_EX3_COUNTER_DEFINED
#define CH5_EX3_COUNTER_DEFINED
int next_counter(void) {
    static int c = 0; // chỉ khởi tạo 1 lần
    c++;
    return c;
}
#endif

# %% [markdown]
# #### Ví dụ 4 — Đệ quy factorial (có base case)
# - Mục tiêu: thấy rõ “điểm dừng” và cách hàm quay lui.

# %%
#include <stdio.h>

int fact(int n);

int main(void) {
    int n = 5;
    printf("%d! = %d\n", n, fact(n));
    return 0;
}

#ifndef CH5_EX4_FACT_DEFINED
#define CH5_EX4_FACT_DEFINED
int fact(int n) {
    // Base case: 0! = 1, 1! = 1
    if (n <= 1) {
        return 1;
    }
    return n * fact(n - 1);
}
#endif

# %% [markdown]
# ### Luyện tập
# 1. Viết hàm `int isEven(int n)` trả về 1 nếu chẵn, 0 nếu lẻ.
# 2. Viết hàm `int sumToN(int n)` tính tổng 1..n.
# 3. Vì sao thay đổi biến tham số trong hàm không làm đổi biến gốc?
#
# <details>
# <summary>Solution</summary>
#
# Gợi ý:
# - `isEven`: kiểm tra `n % 2 == 0`.
# - `sumToN`: dùng vòng lặp hoặc công thức `n*(n+1)/2`.
# - Tham số truyền theo giá trị nên hàm nhận bản sao.
# </details>

# %%
#include <stdio.h>

int isEven(int n)
{
  return ((n%2)==0) ? 1 : 0;
}

int main()
{
  printf("%d", isEven(51));
}

# %%
#include <stdio.h>

int sumToN(int n)
{
  int sum = 0;
  int s = 0;
  while(s<=n){
    sum = sum + s;
    s++;
  }
  return sum;
}

int main()
{
  int n;
  printf("n = ");
  scanf("%d", &n);
  printf("Sum to %d is %d", n, sumToN(n));
}

# %% [markdown]
# ### Lỗi thường gặp
# - Khai báo prototype khác với định nghĩa.
# - Quên `return` trong hàm có kiểu trả về.
# - Đặt tên biến cục bộ trùng tên biến ngoài gây nhầm lẫn.
#
# ### Tóm tắt
# - Hàm giúp tái sử dụng và tổ chức code.
# - Prototype nên đặt trước `main` nếu định nghĩa ở sau.
# - Truyền tham số theo giá trị không đổi biến gốc.
#
# ### Checkpoint quiz
# 1. Prototype dùng để làm gì?
# 2. Hàm `void` có cần `return` không?
# 3. Tham số truyền theo giá trị có thay đổi biến gốc không?
#
# <details>
# <summary>Đáp án</summary>
#
# 1. Thông báo chữ ký hàm cho trình biên dịch.
# 2. Không bắt buộc.
# 3. Không.
# </details>

# %% [markdown]
# <a id="ch6"></a>
# ## Chương 6. Array (Mảng) 1D/2D
#
# **Prerequisites**
# - Chương 4 (vòng lặp).
#
# **Learning outcomes**
# - Truy cập mảng đúng chỉ số (0..n-1) và tránh lỗi off-by-one.
# - Hiểu khởi tạo mảng và quy tắc “thiếu phần tử thì tự động = 0” (khi có init).
# - Khai báo/khởi tạo mảng 2D và duyệt bằng vòng lặp lồng nhau.
# - Biết vì sao khi truyền mảng vào hàm phải truyền kèm `n` (mức thi cơ bản).
#
# ### Giải thích
#
# #### 1) Mảng 1D và chỉ số 0..n-1
# - `int a[5];` có 5 phần tử: `a[0]` ... `a[4]`.
# - Vòng lặp chuẩn: `for (i = 0; i < n; i++)`.
#
# Bẫy: `i <= n` sẽ đi tới `a[n]` (vượt biên, gây UB, thường không báo lỗi khi compile).
# `
#
# #### 2) Khởi tạo mảng và “zero-fill”
# - Nếu bạn **có** danh sách khởi tạo `{...}` nhưng **không đủ phần tử**, phần còn lại sẽ tự động là `0`.
#   - Ví dụ: `int a[5] = {1, 2};` → `a[2]=a[3]=a[4]=0`.
# - Nếu bạn **không khởi tạo**: `int a[5];` → giá trị ban đầu **không xác định**.
#
# #### 3) Mảng 2D (row-major) và khởi tạo
# - `int b[m][n]` là m hàng, mỗi hàng n cột.
# - Duyệt: 2 vòng lặp lồng nhau.
#
# #### 4) Truyền mảng vào hàm: vì sao cần `n`
# Khi truyền mảng vào hàm, bạn thường viết `f(a, n)`. Lý do:
# - Trong hàm, tham số kiểu `int a[]` **không còn giữ thông tin “mảng dài bao nhiêu”**:
#
# Trong C/C++, khi bạn “truyền mảng vào hàm” như `f(a)`, thì **mảng bị “rụng” (decay) thành con trỏ** tới phần tử đầu tiên.
#
# - Ở `main`: `int a[5];` là **mảng** 5 phần tử.
# - Khi gọi hàm: `f(a);` thì `a` được biến thành `int *` (địa chỉ `&a[0]`).
# - Vì vậy trong hàm, khai báo kiểu `int a[]` thực chất được hiểu như **`int *a`**, nên **không còn biết dài bao nhiêu phần tử**.
#
# Hệ quả: `sizeof(a)` **trong hàm** sẽ ra kích thước **con trỏ** (4 hoặc 8 bytes), không phải kích thước cả mảng → không suy ra được `n`.
#
# - Vì vậy đề thi hay gài bẫy `sizeof(a)` trong hàm.
#
# > Phần “bản chất địa chỉ/con trỏ” sẽ học kỹ hơn ở Chương 7–8. Ở đây chỉ cần nhớ: muốn xử lý mảng trong hàm thì **phải truyền kèm kích thước**.
#
# ### Ví dụ
#
# #### Ví dụ 1 — Tính tổng mảng 1D (pattern chuẩn)
# - Mục tiêu: thói quen chuẩn: truyền mảng + truyền `n`.

# %%
#include <stdio.h>

int sum_array(const int a[], int n);

int main(void) {
    int a[5] = {1, 2, 3, 4, 5};
    printf("sum = %d\n", sum_array(a, 5));
    return 0;
}

#ifndef CH6_EX1_SUM_DEFINED
#define CH6_EX1_SUM_DEFINED
int sum_array(const int a[], int n) {
    int s = 0;
    for (int i = 0; i < n; i++) {
        s += a[i];
    }
    return s;
}
#endif

# %% [markdown]
# #### Ví dụ 2 — Khởi tạo thiếu phần tử: phần còn lại tự động = 0
# - Mục tiêu: đọc đề init mảng kiểu `{1,2}`.

# %% [markdown]
# #include <stdio.h>
#
# {
#     int a[5] = {1, 2};
#
#     for (int i = 0; i < 5; i++) {
#         printf("a[%d] = %d\n", i, a[i]);
#     }
#
#     // Nếu bạn viết: int b[5]; (không init) thì b[i] là "không xác định".
# }

# %% [markdown]
# #### Ví dụ 3 — Mảng 2D và hàm in ma trận (tham số đúng)
# - Mục tiêu: nhớ cú pháp: tham số 2D phải biết số cột.
# - Bẫy: `int **` KHÔNG tương đương `int a[R][C]`.

# %%
#include <stdio.h>

void print2d(const int a[][3], int rows);

int main(void) {
    int b[2][3] = {
        {1, 2, 3},
        {4, 5, 6}
    };

    print2d(b, 2);
    return 0;
}

#ifndef CH6_EX3_PRINT2D_DEFINED
#define CH6_EX3_PRINT2D_DEFINED
void print2d(const int a[][3], int rows) {
    for (int r = 0; r < rows; r++) {
        for (int c = 0; c < 3; c++) {
            printf("%d ", a[r][c]);
        }
        printf("\n");
    }
}
#endif

# %% [markdown]
# #### Ví dụ 4 — Bẫy `sizeof`: ngoài mảng vs trong hàm
# - Mục tiêu: thấy `sizeof(a)` ngoài hàm ra "tổng byte", nhưng trong hàm lại khác.

# %%
#include <stdio.h>

void print_size(const int a[]);

int main(void) {
    int a[10] = {0};

    printf("Ngoai ham: sizeof(a) = %zu bytes\n", sizeof(a));
    print_size(a);
    return 0;
}

#ifndef CH6_EX4_SIZE_DEFINED
#define CH6_EX4_SIZE_DEFINED
void print_size(const int a[]) {
    // Trong tham số hàm, a[] được xử lý như một con trỏ => sizeof(a) ra sizeof(pointer)
    printf("Trong ham:  sizeof(a) = %zu bytes\n", sizeof(a));
}
#endif

# %%
//Ví dụ đúng
void f(int a[], int n) {           // a là int*
  for (int i = 0; i < n; i++) { /* dùng a[i] */ }
}

int main() {
  int a[] = {1,2,3,4,5};
  f(a, (int)(sizeof(a)/sizeof(a[0])));  // tính n ở ngoài rồi truyền vào
}
# Out:
#   Cell In[3], line 1
#     void f(int a[], int n) {           // a là int*
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Luyện tập
# 1. Tìm giá trị lớn nhất trong mảng `int a[5]`.
# 2. Tính trung bình cộng của một mảng `double` có 4 phần tử.
# 3. Khai báo mảng 2D `int c[3][4]` và in toàn bộ phần tử.
#
# <details>
# <summary>Solution</summary>
#
# Gợi ý:
# - Duyệt mảng bằng vòng lặp, cập nhật `max`.
# - Trung bình: `sum / 4`.
# - Với mảng 2D, dùng hai vòng lặp lồng nhau.
# </details>

# %% [markdown]
# ### Lỗi thường gặp
# - Truy cập chỉ số ngoài phạm vi mảng.
# - Nhầm kích thước mảng khi dùng `sizeof`.
# - Quên khởi tạo khiến giá trị rác.
#
# ### Tóm tắt
# - Mảng dùng chỉ số từ 0.
# - Mảng 2D là mảng của mảng.
# - Khởi tạo thiếu phần tử sẽ tự điền 0.
#
# ### Checkpoint quiz
# 1. Chỉ số cuối cùng của mảng `int a[10]` là bao nhiêu?
# 2. Vì sao truy cập `a[10]` là lỗi?
# 3. Khi khởi tạo `int x[3] = {1};` thì `x[1]` và `x[2]` là bao nhiêu?
#
# <details>
# <summary>Đáp án</summary>
#
# 1. 9.
# 2. Vượt phạm vi mảng.
# 3. Đều bằng 0.
# </details>

# %% [markdown]
# <a id="ch7"></a>
# ## Chương 7. Địa chỉ bộ nhớ và con trỏ cơ bản
#
# **Prerequisites**
# - Chương 2 (kiểu dữ liệu).
# - Chương 5 (hàm — để hiểu ví dụ swap).
#
# **Learning outcomes**
# - Hiểu “địa chỉ bộ nhớ” là gì và vì sao biến nào cũng có địa chỉ.
# - Nắm chắc 3 ký hiệu quan trọng: `&` (lấy địa chỉ), `*` (giải tham chiếu), `NULL`.
# - Viết được đoạn code dùng con trỏ để **đọc/ghi** giá trị của biến thông qua địa chỉ.
# - Hiểu vì sao `scanf/sscanf` cần truyền **địa chỉ**.
#
# ### Giải thích
#
# #### 1) Địa chỉ bộ nhớ là gì?
# Hãy tưởng tượng mỗi biến là một “hộp” trong RAM. Hộp này có:
# - **Giá trị** (value) đang chứa.
# - **Địa chỉ** (address) — giống như “số nhà” của hộp.
#
# #### 2) Con trỏ (pointer) là gì?
# - Con trỏ là biến dùng để **lưu địa chỉ** của biến khác.
# - Ví dụ: `int *p = &x;` nghĩa là `p` đang giữ địa chỉ của `x`.
#
# Ký hiệu quan trọng:
# - `&x`: lấy địa chỉ của `x`.
# - `*p`: lấy **giá trị tại địa chỉ** mà `p` đang trỏ tới (gọi là giải tham chiếu).
#
# #### 3) `NULL` và an toàn khi dereference
# - `NULL` (hoặc `nullptr` trong C++) biểu thị “không trỏ tới đâu”.
# - Dereference `*p` khi `p == NULL` → lỗi runtime (crash/UB).
#
# Thói quen tốt:
# - Khởi tạo con trỏ về `NULL` nếu chưa trỏ tới đâu.
# - Luôn check `p != NULL` trước khi dùng `*p`.
#
# #### 4) Vì sao `scanf` cần địa chỉ?
# `scanf/sscanf` phải ghi kết quả vào biến của bạn, nên nó cần biết **nơi để ghi** → chính là **địa chỉ**.
#
# Bẫy thi cực hay gặp:
# - `scanf("%d", a);` là sai (vì `a` là giá trị, không phải địa chỉ).
# - Đúng: `scanf("%d", &a);`
#
# ### Ví dụ
#
# #### Ví dụ 1 — Trực quan hóa `&` và `*`
# - Mục tiêu: nhìn rõ 3 thứ: `&x` (địa chỉ), `p` (địa chỉ), và `*p` (giá trị).
# - Lưu ý: địa chỉ in ra có thể khác nhau mỗi lần chạy.

# %%
#include <stdio.h>

int main(void) {
    int x = 10;
    int* p = &x; // p lưu địa chỉ của x

    printf("Gia tri x = %d\n", x);

    // %p dùng để in địa chỉ; cast về (void*) để đúng format
    printf("Dia chi &x = %p\n", (void*)&x);
    printf("Gia tri p  = %p\n", (void*)p);

    printf("Gia tri *p = %d\n", *p);

    // Ghi thông qua con trỏ: đổi giá trị của x
    *p = 20;
    printf("Sau *p = 20 -> x = %d\n", x);
    return 0;
}

# %% [markdown]
# #### Ví dụ 2 — Swap đúng bằng con trỏ (đổi biến gốc)
# - Mục tiêu: áp dụng con trỏ để sửa giá trị biến bên ngoài hàm (cầu nối từ Chương 5).

# %%
#include <stdio.h>

void swap_int(int* a, int* b);

int main(void) {
    int a = 3;
    int b = 5;

    printf("Truoc swap: a=%d b=%d\n", a, b);
    swap_int(&a, &b);
    printf("Sau swap:   a=%d b=%d\n", a, b);
    return 0;
}

#ifndef CH7_EX2_SWAP_DEFINED
#define CH7_EX2_SWAP_DEFINED
void swap_int(int* a, int* b) {
    int tmp = *a;
    *a = *b;
    *b = tmp;
}
#endif

# %% [markdown]
# #### Ví dụ 3 — `scanf/sscanf` cần địa chỉ (bẫy `&`)
# - Mục tiêu: hiểu bản chất: hàm I/O phải ghi vào biến → cần địa chỉ.
# - Để dễ chạy trong notebook, ta dùng `sscanf` đọc từ chuỗi thay vì nhập tay.

# %%
#include <stdio.h>

int main(void) {
    const char* input = "12 34";
    int a = 0;
    int b = 0;

    // ĐÚNG: truyền địa chỉ &a, &b
    sscanf(input, "%d %d", &a, &b);
    printf("a=%d b=%d sum=%d\n", a, b, a + b);

    // SAI (comment): truyền giá trị a thay vì địa chỉ
    //sscanf(input, "%d", a);

    // Lưu ý thêm (mức thi): với mảng char s[], ta truyền s (đã là địa chỉ phần tử đầu)
    // char s[10]; scanf("%9s", s);  // KHÔNG dùng &s
    return 0;
}

# %% [markdown]
# #### Ví dụ 4 — `NULL` check + short-circuit
# - Mục tiêu: thói quen an toàn: luôn check con trỏ trước khi dereference.

# %%
#include <stdio.h>

int main(void) {
    int* p = NULL;

    if (p != NULL && *p > 0) {
        // Không bao giờ vào đây vì p == NULL
        printf("*p = %d\n", *p);
    } else {
        printf("An toan: p == NULL, khong dereference\n");
    }
    return 0;
}

# %% [markdown]
# ### Luyện tập
# 1. Viết hàm `void swap(int *a, int *b)` để đổi giá trị hai biến.
# 2. In ra địa chỉ của một biến `int` (dùng `%p`).
# 3. Nếu `p` là con trỏ `int*`, `*p` biểu diễn gì?
#
# <details>
# <summary>Solution</summary>
#
# Gợi ý:
# - Dùng biến tạm `temp`.
# - Ép kiểu `(void*)` khi in `%p`.
# - `*p` là giá trị mà `p` trỏ tới.
# </details>

# %% [markdown]
# ### Lỗi thường gặp
# - Quên `&` khi dùng `scanf`.
# - Giải tham chiếu con trỏ `NULL`.
# - Khai báo sai kiểu con trỏ (ví dụ `int *` trỏ tới `double`).
#
# ### Tóm tắt
# - Con trỏ lưu địa chỉ biến khác.
# - `&` lấy địa chỉ, `*` truy cập giá trị.
# - `scanf` cần địa chỉ để ghi dữ liệu.
#
# ### Checkpoint quiz
# 1. `int *p = &x;` nghĩa là gì?
# 2. Toán tử nào dùng để giải tham chiếu?
# 3. Vì sao `scanf("%d", x);` là sai?
#
# <details>
# <summary>Đáp án</summary>
#
# 1. `p` là con trỏ trỏ tới `x`.
# 2. `*`.
# 3. Vì cần truyền địa chỉ: phải dùng `&x`.
# </details>

# %% [markdown]
# <a id="ch8"></a>
# ## Chương 8. Con trỏ & mảng, con trỏ hàm
#
# **Prerequisites**
# - Chương 6 (mảng).
# - Chương 7 (con trỏ).
#
# **Learning outcomes**
# - Hiểu quy tắc “array decay”: trong nhiều biểu thức, tên mảng `a` được dùng như địa chỉ `&a[0]`.
# - Duyệt mảng bằng con trỏ và phân biệt `*(p+i)` với `*p+i`.
# - Phân biệt `a`, `&a`, `&a[0]` (bẫy hay gặp).
# - Khai báo và dùng con trỏ hàm: `int (*pf)(int,int)`.
# - Dùng mảng con trỏ hàm để tạo “menu” chọn hành vi.
#
# ### Giải thích
#
# #### 1) Mảng và con trỏ liên quan thế nào?
# Với mảng `int a[4]`:
# - `a[i]` tương đương `*(a + i)`.
# - `a` thường được hiểu như “địa chỉ phần tử đầu” (`&a[0]`).
#
# Bẫy rất hay gặp:
# - `*(p+i)` khác `*p+i` do ưu tiên toán tử.
#
# #### 2) `a` vs `&a` vs `&a[0]`
# - `a` và `&a[0]` có cùng **giá trị địa chỉ**, nhưng kiểu khác nhau trong một số ngữ cảnh.
# - `&a` là “con trỏ tới cả mảng” (tăng `&a + 1` sẽ nhảy theo **kích thước cả mảng**).
#
# #### 3) Con trỏ hàm
# - Con trỏ hàm lưu “địa chỉ của hàm”.
# - Cú pháp quan trọng: dấu ngoặc `(*pf)`.
#   - Đúng: `int (*pf)(int,int);`
#   - Sai (nhầm): `int *pf(int,int);` (đây là **hàm trả về con trỏ**).
#
# ### Ví dụ
#
# #### Ví dụ 1 — Duyệt mảng bằng con trỏ (pointer arithmetic)
# - Mục tiêu: đọc đúng `*(p+i)` và tránh bẫy `*p+i`.

# %%
#include <stdio.h>

int main(void) {
    int a[4] = {1, 2, 3, 4};
    int* p = a; // p trỏ tới a[0]

    for (int i = 0; i < 4; i++) {
        printf("a[%d]=%d, *(p+%d)=%d\n", i, a[i], i, *(p + i));
    }

    // Bẫy ưu tiên:
    // *p + 1  = ( *p ) + 1
    // *(p+1)  = phần tử kế tiếp
    printf("*p + 1 = %d\n", *p + 1);
    printf("*(p+1) = %d\n", *(p + 1));
    return 0;
}

# %% [markdown]
# #### Ví dụ 2 — Phân biệt `a`, `&a`, `&a[0]`
# - Mục tiêu: thấy sự khác nhau khi cộng thêm 1.

# %%
#include <stdio.h>

int main(void) {
    int a[4] = {0};

    printf("a (=&a[0])   = %p\n", (void*)a);
    printf("&a[0]        = %p\n", (void*)&a[0]);
    printf("&a           = %p\n", (void*)&a);

    printf("a + 1        = %p\n", (void*)(a + 1));
    printf("&a + 1       = %p\n", (void*)(&a + 1));

    // a+1 nhảy 1 phần tử int
    // &a+1 nhảy 1 "mảng" (4 phần tử int)
    return 0;
}

# %% [markdown]
# #### Ví dụ 3 — Con trỏ hàm: trỏ tới add/sub và gọi
# - Mục tiêu: đọc đúng khai báo `int (*pf)(int,int)`.

# %%
#include <stdio.h>

int add(int a, int b);
int sub(int a, int b);

int main(void) {
    int (*pf)(int, int) = add;
    printf("add(7,2) = %d\n", pf(7, 2));

    pf = sub;
    printf("sub(7,2) = %d\n", pf(7, 2));
    return 0;
}

#ifndef CH8_EX3_FUNPTR_DEFINED
#define CH8_EX3_FUNPTR_DEFINED
int add(int a, int b) { return a + b; }
int sub(int a, int b) { return a - b; }
#endif

# %% [markdown]
# #### Ví dụ 4 — “Menu” bằng mảng con trỏ hàm
# - Mục tiêu: dùng `ops[op]` để chọn hàm.

# %%
#include <stdio.h>

int add2(int a, int b);
int sub2(int a, int b);

int main(void) {
    int (*ops[2])(int, int) = {add2, sub2};

    int op = 1; // 0: add, 1: sub
    int a = 10;
    int b = 3;

    if (op < 0 || op >= 2) {
        printf("op out of range\n");
    } else {
        printf("result = %d\n", ops[op](a, b));
    }
    return 0;
}

#ifndef CH8_EX4_MENU_DEFINED
#define CH8_EX4_MENU_DEFINED
int add2(int a, int b) { return a + b; }
int sub2(int a, int b) { return a - b; }
#endif

# %% [markdown]
# ### Luyện tập
# 1. Dùng con trỏ để tính tổng các phần tử mảng `int a[5]`.
# 2. Viết con trỏ hàm trỏ tới hàm `int mul(int a, int b)` và gọi nó.
# 3. Khi `p` là `int*`, `p + 1` dịch địa chỉ thêm bao nhiêu byte?
#
# <details>
# <summary>Solution</summary>
#
# Gợi ý:
# - Duyệt bằng `*(p + i)`.
# - Khai báo `int (*fp)(int,int) = mul;`.
# - Dịch thêm `sizeof(int)` byte.
# </details>

# %% [markdown]
# ### Lỗi thường gặp
# - Dùng sai kiểu con trỏ hàm (sai chữ ký).
# - Vượt phạm vi mảng khi tăng con trỏ.
# - Nhầm `*p++` với `(*p)++`.
#
# ### Tóm tắt
# - Tên mảng thường tương đương địa chỉ phần tử đầu tiên.
# - Số học con trỏ tăng theo kích thước kiểu dữ liệu.
# - Con trỏ hàm lưu địa chỉ của hàm.
#
# ### Checkpoint quiz
# 1. `int *p = a;` có hợp lệ nếu `a` là mảng `int` không?
# 2. Cú pháp đúng của con trỏ hàm nhận 2 `int` và trả về `int`?
# 3. Vì sao cần cẩn thận khi dùng `p++` với con trỏ?
#
# <details>
# <summary>Đáp án</summary>
#
# 1. Có.
# 2. `int (*p)(int, int);`
# 3. Dễ vượt phạm vi mảng gây lỗi.
# </details>

# %% [markdown]
# <a id="ch9"></a>
# ## Chương 9. Chuỗi C và xử lý chuỗi
#
# **Prerequisites**
# - Chương 6 (mảng).
# - Chương 7–8 (địa chỉ, con trỏ — để hiểu `char[]` và tham số hàm).
#
# **Learning outcomes**
# - Hiểu chuỗi C là mảng `char` kết thúc bằng ký tự `\0` (null-terminator).
# - Dùng đúng các hàm cơ bản: `strlen`, `strcmp`, `strcpy`, `strcat`.
# - Biết bẫy `fgets` giữ lại `\n` và cách trim newline.
# - Nhận diện bẫy “so sánh chuỗi bằng `==`” (sai) và bẫy buffer khi trộn `scanf/fscanf` với `fgets`.
#
# ### Giải thích
#
# #### 1) Chuỗi C là gì?
# Chuỗi trong C là:
# - Mảng ký tự `char[]`.
# - Kết thúc bằng ký tự đặc biệt `\0`.
#
# Vì có `\0` nên:
# - `strlen(s)` đếm số ký tự **trước `\0`**.
# - Nếu quên `\0`, chương trình có thể đọc “lố” sang vùng nhớ khác.
#
# #### 2) `fgets` và bẫy newline
# `fgets(buf, n, stdin)` đọc tối đa `n-1` ký tự và luôn đặt `\0` ở cuối.
# - Nếu dòng input có `\n` và còn chỗ trong buffer, `fgets` sẽ giữ lại `\n`.
# - Vì vậy ta thường “trim” `\n` cuối chuỗi.
#
# #### 3) So sánh chuỗi: dùng `strcmp`, không dùng `==`
# - `strcmp(a,b) == 0` nghĩa là 2 chuỗi bằng nhau.
# - `a == b` (với `char[]`) thực chất so **địa chỉ**, không so nội dung.
#
# Bẫy đề hay ra:
# - `if (strcmp(a,b))` không có nghĩa là bằng nhau (vì 0 mới là bằng).
#
# #### 4) Buffer khi trộn đọc số và đọc dòng
# Sau khi đọc số bằng `scanf/fscanf`, thường còn lại `\n` trong buffer.
# Nếu gọi `fgets` ngay, bạn có thể nhận được một dòng rỗng.
#
# ### Ví dụ
#
# #### Ví dụ 1 — Trim newline và đo độ dài bằng `strlen`
# - Mục tiêu: thấy rõ vì sao cần bỏ `\n` khi xử lý chuỗi.

# %%
#include <stdio.h>
#include <string.h>

int main(void) {
    // Giả sử đây là chuỗi vừa đọc được bằng fgets (thường có '\n' ở cuối)
    char name[32] = "An\n";

    printf("Raw: '%s'", name); // in ra sẽ xuống dòng vì có \n

    size_t len = strlen(name);
    if (len > 0 && name[len - 1] == '\n') {
        name[len - 1] = '\0';
    }

    printf("Sau trim: '%s'\n", name);
    printf("strlen(name) = %zu\n", strlen(name));
    return 0;
}

# %% [markdown]
# #### Ví dụ 2 — `strcmp` đúng vs bẫy so sánh `==`
# - Mục tiêu: nhớ: `==` không so nội dung chuỗi.

# %%
#include <stdio.h>
#include <string.h>

int main(void) {
    char a[] = "Hello";
    char b[] = "Hello";

    // a và b là 2 mảng khác nhau => địa chỉ khác nhau
    printf("(a==b) = %d  (so dia chi)\n", a == b);

    printf("strcmp(a,b) = %d\n", strcmp(a, b));
    if (strcmp(a, b) == 0) {
        printf("Noi dung bang nhau\n");
    }
    return 0;
}

# %% [markdown]
# #### Ví dụ 3 — Bẫy buffer: `fscanf` rồi `fgets` đọc ra dòng rỗng
# - Mục tiêu: mô phỏng tình huống “bị skip input” mà không cần nhập tay.
# - Ta dùng `tmpfile()` để tạo một luồng vào giống như stdin.

# %%
#include <stdio.h>
#include <string.h>

int main(void) {
    FILE* fp = tmpfile();
    if (!fp) {
        printf("tmpfile failed\n");
    } else {
        fputs("10\nHello world\n", fp);
        rewind(fp);

        int n = 0;
        char line[64];

        fscanf(fp, "%d", &n);
        printf("n = %d\n", n);

        // Ngay sau fscanf, trong buffer còn lại '\n'
        fgets(line, sizeof(line), fp);
        printf("fgets ngay sau fscanf -> '%s'\n", line);

        // Cách xử lý đơn giản: gọi fgets thêm lần nữa (hoặc consume '\n')
        if (fgets(line, sizeof(line), fp)) {
            size_t len = strlen(line);
            if (len > 0 && line[len - 1] == '\n') {
                line[len - 1] = '\0';
            }
            printf("Dong tiep theo -> '%s'\n", line);
        }

        fclose(fp);
    }
    return 0;
}

# %% [markdown]
# #### Ví dụ 4 — Nối chuỗi “an toàn” với `strncat`
# - Mục tiêu: tránh tràn buffer khi nối.
# - Ý tưởng: mỗi lần nối, chỉ cho phép nối tối đa "còn trống" trong buffer.

# %%
#include <stdio.h>
#include <string.h>

int main(void) {
    char dst[16] = "Hello";
    const char* src = "World";

    // Nối thêm 1 khoảng trắng (chừa 1 byte cho '\0')
    size_t remain = sizeof(dst) - strlen(dst) - 1;
    strncat(dst, " ", remain);

    remain = sizeof(dst) - strlen(dst) - 1;
    strncat(dst, src, remain);

    printf("dst = '%s'\n", dst);

    // Lưu ý: strcat/strcpy KHÔNG tự kiểm tra size -> rất dễ overflow.
    return 0;
}

# %% [markdown]
# ### Luyện tập
# 1. Viết chương trình đếm số ký tự trong chuỗi (không tính `\0`).
# 2. Nhập một chuỗi và đổi tất cả chữ hoa thành chữ thường.
# 3. So sánh hai chuỗi và in ra chuỗi lớn hơn theo thứ tự từ điển.
#
# <details>
# <summary>Solution</summary>
#
# Gợi ý:
# - Dùng `strlen`.
# - Dùng hàm `tolower` từ `ctype.h`.
# - `strcmp(s1, s2) > 0` thì `s1` lớn hơn.
# </details>

# %% [markdown]
# ### Lỗi thường gặp
# - Dùng `gets` gây tràn bộ đệm.
# - Quên xử lý ký tự xuống dòng khi dùng `fgets`.
# - Quên kích thước đủ lớn cho chuỗi đích khi `strcpy/strcat`.
#
# ### Tóm tắt
# - Chuỗi C là mảng `char` kết thúc bởi `\0`.
# - `fgets` an toàn hơn `gets`.
# - `string.h` cung cấp nhiều hàm xử lý chuỗi.
#
# ### Checkpoint quiz
# 1. Ký tự kết thúc chuỗi C là gì?
# 2. Vì sao `fgets` an toàn hơn `gets`?
# 3. Hàm nào dùng để so sánh hai chuỗi C?
#
# <details>
# <summary>Đáp án</summary>
#
# 1. `\0`.
# 2. Vì giới hạn số ký tự đọc vào buffer.
# 3. `strcmp`.
# </details>

# %% [markdown]
# <a id="ch10"></a>
# ## Chương 10. Cấp phát bộ nhớ động
#
# **Prerequisites**
# - Chương 7–8 (con trỏ).
#
# **Learning outcomes**
# - Biết dùng `malloc/calloc/realloc/free` theo pattern chuẩn (check NULL, free đúng 1 lần).
# - Hiểu stack vs heap và vì sao heap phải tự `free`.
# - Nhận diện lỗi thường gặp: memory leak, double free, use-after-free.
# - Biết cấp phát chuỗi động đúng quy tắc `n + 1` cho `\0`.
#
# ### Giải thích
#
# #### 1) Stack vs heap
# - **Stack**: biến cục bộ (trong hàm) được cấp phát tự động và thu hồi khi ra khỏi scope.
# - **Heap**: vùng nhớ động — bạn tự cấp phát và tự giải phóng.
#
# #### 2) `malloc/calloc/realloc/free`
# - `malloc(nBytes)`: cấp phát `nBytes` byte (không khởi tạo).
# - `calloc(count, size)`: cấp phát và khởi tạo 0.
# - `realloc(p, newSize)`: đổi kích thước vùng nhớ.
# - `free(p)`: giải phóng.
#
# Pattern chuẩn (đề rất hay hỏi):
# - Luôn check `p != NULL` sau `malloc/calloc/realloc`.
# - Khi `realloc`, nên dùng biến tạm:
#   - `tmp = realloc(p, newSize); if(tmp) p = tmp; else giữ p cũ`.
#
# > Ghi chú: notebook đang chạy C++17. Trong C++ cần cast kết quả `malloc` về đúng kiểu. Trong C thuần thì không cần cast.
#
# #### 3) Lỗi thường gặp
# - Memory leak: quên `free`.
# - Double free: `free` cùng con trỏ 2 lần (UB).
# - Use-after-free: `free` xong vẫn truy cập.
#
# Thói quen tốt: `free(p); p = NULL;`
#
# #### 4) Cấp phát chuỗi động
# Chuỗi C cần `\0` ở cuối, nên nếu muốn chứa `n` ký tự thì phải cấp phát `n+1`.
#
# ### Ví dụ
#
# #### Ví dụ 1 — `malloc` mảng int + tính tổng + `free`
# - Mục tiêu: pattern chuẩn: `n * sizeof(int)` + check NULL + free.

# %%
#include <stdio.h>
#include <stdlib.h>

int main(void) {
    int n = 5;

    // Trong C++ cần cast; trong C thuần thì không cần.
    int* a = (int*)malloc(n * sizeof(int));
    if (a == NULL) {
        printf("malloc failed\n");
    } else {
        for (int i = 0; i < n; i++) {
            a[i] = i + 1;
        }

        int sum = 0;
        for (int i = 0; i < n; i++) {
            sum += a[i];
        }
        printf("sum = %d\n", sum);

        free(a);
        a = NULL;
    }
    return 0;
}

# %% [markdown]
# #### Ví dụ 2 — `realloc` an toàn với biến tạm
# - Mục tiêu: tránh mất con trỏ khi `realloc` thất bại.

# %%
#include <stdio.h>
#include <stdlib.h>

int main(void) {
    int n = 3;
    int* p = (int*)malloc(n * sizeof(int));
    if (!p) {
        printf("malloc failed\n");
    } else {
        for (int i = 0; i < n; i++) p[i] = i + 1;

        int newN = 6;
        int* tmp = (int*)realloc(p, newN * sizeof(int));
        if (!tmp) {
            // p vẫn còn hợp lệ, ta phải free p trước khi kết thúc
            printf("realloc failed, p con hop le\n");
            free(p);
        } else {
            p = tmp;

            for (int i = n; i < newN; i++) p[i] = i + 1;

            int sum = 0;
            for (int i = 0; i < newN; i++) sum += p[i];
            printf("sum(new) = %d\n", sum);

            free(p);
        }
    }
    return 0;
}

# %% [markdown]
# #### Ví dụ 3 — `free` + set `NULL` để tránh double free
# - Mục tiêu: nhớ thói quen giúp tránh lỗi nghiêm trọng.

# %%
#include <stdio.h>
#include <stdlib.h>

int main(void) {
    int* p = (int*)malloc(sizeof(int));
    if (!p) {
        printf("malloc failed\n");
    } else {
        *p = 42;
        printf("*p = %d\n", *p);

        free(p);
        p = NULL;

        // free(NULL) là an toàn.
        free(p);
        printf("freed safely\n");

        // DANG SAI (comment): dùng sau free
        //printf("%d\n", *p);
    }
    return 0;
}

# %% [markdown]
# #### Ví dụ 4 — Chuỗi động: cấp phát `n+1` cho `\0`
# - Mục tiêu: tránh quên null-terminator.

# %%
#include <stdio.h>
#include <stdlib.h>
#include <string.h>

int main(void) {
    const char* src = "hello";
    size_t n = strlen(src);

    char* s = (char*)malloc((n + 1) * sizeof(char));
    if (!s) {
        printf("malloc failed\n");
    } else {
        // Copy cả '\0'
        memcpy(s, src, n + 1);

        printf("s = %s\n", s);

        free(s);
    }
    return 0;
}

# %% [markdown]
# ### Luyện tập
# 1. Cấp phát mảng `double` gồm `n` phần tử, tính tổng rồi giải phóng.
# 2. Dùng `realloc` để tăng kích thước mảng từ 5 lên 10 phần tử.
# 3. Vì sao cần kiểm tra `NULL` sau khi `malloc`?
#
# <details>
# <summary>Solution</summary>
#
# Gợi ý:
# - `double *a = malloc(n * sizeof(double));`
# - `realloc(arr, 10 * sizeof(int));`
# - `malloc` có thể thất bại khi thiếu bộ nhớ.
# </details>

# %% [markdown]
# ### Lỗi thường gặp
# - Quên `free` gây rò rỉ bộ nhớ.
# - Dùng `free` rồi vẫn truy cập (con trỏ treo).
# - Nhầm `sizeof(int*)` với `sizeof(int)` khi cấp phát.
#
# ### Tóm tắt
# - `malloc/calloc/realloc` cấp phát trên heap.
# - Luôn `free` khi không dùng nữa.
# - Kiểm tra `NULL` để tránh lỗi khi cấp phát thất bại.
#
# ### Checkpoint quiz
# 1. `calloc` khác `malloc` ở điểm nào?
# 2. Điều gì xảy ra nếu dùng `free` hai lần trên cùng một con trỏ?
# 3. Khi nào nên dùng `realloc`?
#
# <details>
# <summary>Đáp án</summary>
#
# 1. `calloc` khởi tạo vùng nhớ về 0.
# 2. Lỗi nghiêm trọng (undefined behavior).
# 3. Khi cần thay đổi kích thước vùng nhớ đã cấp phát.
# </details>

# %% [markdown]
# <a id="ch11"></a>
# ## Chương 11. struct, enum, typedef
#
# **Prerequisites**
# - Chương 6 (mảng).
# - Chương 7 (con trỏ) — để hiểu `->`.
#
# **Learning outcomes**
# - Khai báo `struct` để gom nhóm dữ liệu liên quan và truy cập bằng `.`.
# - Dùng con trỏ struct và truy cập bằng `->` (và hiểu `p->x` ≡ `(*p).x`).
# - Dùng `typedef` để đặt tên kiểu gọn hơn.
# - Hiểu `enum` là các hằng số nguyên có tên và dùng được với `switch`.
# - Nhận biết bẫy `sizeof(struct)` có thể lớn hơn tổng member do **padding/alignment**.
#
# ### Giải thích
#
# #### 1) `struct` dùng để làm gì?
# `struct` gom nhiều trường (field) thành một kiểu dữ liệu mới.
# Ví dụ bài thi hay gặp: Sinh viên (tên, GPA), Điểm (x, y), …
#
# Truy cập:
# - Biến struct: `s.gpa`
#
# #### 2) Con trỏ struct và toán tử `->`
# Nếu `p` là con trỏ tới struct:
# - `p->gpa` tương đương `(*p).gpa`.
#
# Bẫy:
# - Nhầm `.` và `->`.
#
# #### 3) `typedef`
# Giúp đặt bí danh cho kiểu, code gọn hơn (đặc biệt với struct).
#
# #### 4) `enum`
# `enum` là tập các hằng số nguyên có tên.
# - Nếu không gán giá trị, mặc định tăng dần từ 0.
# - Dùng enum trong `switch` giúp code rõ nghĩa.
#
# #### 5) Padding/alignment và `sizeof(struct)`
# Compiler có thể chèn “khoảng đệm” để căn chỉnh bộ nhớ.
# Vì vậy `sizeof(struct)` **không nhất thiết** bằng tổng `sizeof` các member.
#
# ### Ví dụ
#
# #### Ví dụ 1 — `typedef struct` + khởi tạo + in dữ liệu
# - Mục tiêu: thấy cách dùng `typedef`, và phân biệt `char[]` (chuỗi C) trong struct.

# %%
#include <stdio.h>

#ifndef CH11_TYPES_DEFINED
#define CH11_TYPES_DEFINED

typedef struct {
    char name[30];
    double gpa;
} Student;

#endif

int main(void) {
    // Khởi tạo nhanh (cú pháp C/C++ đều chấp nhận)
    Student s = {"An", 3.5};

    printf("Name: %s\n", s.name);
    printf("GPA : %.2f\n", s.gpa);
    return 0;
}

# %% [markdown]
# #### Ví dụ 2 — Con trỏ struct: `->` và `(*p).x`
# - Mục tiêu: đọc đề dạng con trỏ struct.

# %%
#include <stdio.h>

#ifndef CH11_TYPES_DEFINED
#define CH11_TYPES_DEFINED

typedef struct {
    char name[30];
    double gpa;
} Student;

#endif

int main(void) {
    Student s = {"Binh", 2.8};
    Student* p = &s;

    // Hai cách viết tương đương:
    p->gpa = 3.2;
    (*p).gpa = 3.4;

    printf("%s GPA=%.1f\n", p->name, p->gpa);
    return 0;
}

# %% [markdown]
# #### Ví dụ 3 — `enum` + `switch`
# - Mục tiêu: hiểu enum là số nguyên có tên; dùng switch rõ nghĩa.

# %%
#include <stdio.h>

#ifndef CH11_ENUM_DEFINED
#define CH11_ENUM_DEFINED

enum Level { LOW = 1, MEDIUM, HIGH };

#endif

int main(void) {
    enum Level lv = MEDIUM;

    switch (lv) {
        case LOW:
            printf("LOW\n");
            break;
        case MEDIUM:
            printf("MEDIUM\n");
            break;
        case HIGH:
            printf("HIGH\n");
            break;
        default:
            printf("UNKNOWN\n");
            break;
    }

    // In enum như int (vì bản chất enum là số nguyên)
    printf("MEDIUM = %d\n", MEDIUM);
    return 0;
}

# %% [markdown]
# #### Ví dụ 4 — Padding: đổi thứ tự member làm đổi `sizeof(struct)`
# - Mục tiêu: bẫy thi cực hay: sizeof(struct) không bằng tổng member.

# %%
#include <stdio.h>

#ifndef CH11_PADDING_DEFINED
#define CH11_PADDING_DEFINED

typedef struct {
    char c;
    int x;
} A;

typedef struct {
    int x;
    char c;
} B;

#endif

int main(void) {
    printf("sizeof(A) = %zu\n", sizeof(A));
    printf("sizeof(B) = %zu\n", sizeof(B));

    // Thường sizeof(A) và sizeof(B) có thể khác nhau do padding.
    return 0;
}

# %% [markdown]
# ### Luyện tập
# 1. Tạo `struct Point` gồm `x`, `y` và in tọa độ.
# 2. Tạo `enum Color` với `RED=1, GREEN, BLUE` và in giá trị.
# 3. Khi nào dùng `.` và khi nào dùng `->` với struct?
#
# <details>
# <summary>Solution</summary>
#
# Gợi ý:
# - `Point p = {1.0, 2.0};` rồi `p.x`.
# - `GREEN` sẽ có giá trị 2.
# - Dùng `.` với biến struct, `->` với con trỏ tới struct.
# </details>

# %% [markdown]
# ### Lỗi thường gặp
# - Quên khai báo `typedef` khiến cú pháp dài.
# - Nhầm `.` và `->`.
# - Hiểu sai giá trị tự động tăng của `enum`.
#
# ### Tóm tắt
# - `struct` gom nhóm dữ liệu liên quan.
# - `typedef` giúp tên kiểu ngắn gọn.
# - `enum` tạo các hằng số có ý nghĩa.
#
# ### Checkpoint quiz
# 1. `enum Level { LOW=1, MEDIUM, HIGH };` thì `HIGH` bằng bao nhiêu?
# 2. Padding là gì?
# 3. `typedef` giúp gì trong code?
#
# <details>
# <summary>Đáp án</summary>
#
# 1. 3.
# 2. Khoảng đệm để căn chỉnh bộ nhớ.
# 3. Tạo bí danh kiểu, giúp code ngắn gọn.
# </details>

# %% [markdown]
# <a id="ch12"></a>
# ## Chương 12. File I/O trong C
#
# **Prerequisites**
# - Chương 7 (con trỏ) — để hiểu `FILE*`.
# - Chương 9 (chuỗi) — để hiểu đọc theo dòng.
#
# **Learning outcomes**
# - Hiểu `FILE` / `FILE*`: `FILE` là kiểu do thư viện chuẩn cung cấp đại diện cho **file stream**, `FILE*` là con trỏ trỏ tới stream.
# - Mở/đóng file đúng: `fopen` → check NULL → đọc/ghi → `fclose`.
# - Chọn đúng mode: `r/w/a` (và `b` cho nhị phân).
# - Đọc file theo dòng đúng pattern: `while (fgets(...))` (tránh `while(!feof)`).
#
# ### Giải thích
#
# #### 1) `FILE` và `FILE*` là gì?
# - `FILE` là kiểu dữ liệu do thư viện chuẩn cung cấp, đại diện cho **trạng thái của một luồng file (file stream)**.
# - `FILE* fp` là **con trỏ** trỏ tới đối tượng stream đó.
#
# Vì sao dùng con trỏ?
# - `fopen` cần trả về “một stream đã được mở”, và nếu mở thất bại thì trả về `NULL`.
#
# #### 2) Quy trình chuẩn khi làm bài
# 1. `FILE* fp = fopen(...);`
# 2. `if (!fp) { ... }`
# 3. Đọc/ghi (`fprintf`, `fgets`, ...)
# 4. `fclose(fp);`
#
# Bẫy:
# - Quên `fclose` → dữ liệu có thể chưa flush hết.
# - Dùng `fp` sau `fclose`.
#
# #### 3) Mode mở file
# - `"r"`: đọc.
# - `"w"`: ghi (tạo mới/ghi đè).
# - `"a"`: ghi thêm (append).
# - Thêm `b` cho nhị phân trên Windows: `"rb"`, `"wb"`.
#
# #### 4) Đọc file tới EOF đúng cách
# - Đúng: `while (fgets(buf, sizeof(buf), fp)) { ... }`
# - Sai phổ biến: `while (!feof(fp)) { fgets(...); }`
#
# ### Ví dụ
#
# #### Ví dụ 1 — Ghi file text (mode `w`) + check NULL
# - Mục tiêu: pattern chuẩn: fopen → check → fprintf → fclose.

# %%
#include <stdio.h>

int main(void) {
    const char* path = "ch12_ex1.txt";
    FILE* fp = fopen(path, "w");
    if (!fp) {
        printf("Khong mo duoc file\n");
    } else {
        fprintf(fp, "Dong 1\n");
        fprintf(fp, "Dong 2\n");

        fclose(fp);
        printf("Da ghi xong: %s\n", path);
    }
    return 0;
}

# %% [markdown]
# #### Ví dụ 2 — `w` (ghi đè) vs `a` (append)
# - Mục tiêu: nhớ mode nào ghi thêm, mode nào ghi đè.

# %%
#include <stdio.h>

int main(void) {
    const char* path = "ch12_ex2.txt";

    // 1) Ghi đè bằng "w"
    FILE* fp = fopen(path, "w");
    if (!fp) {
        printf("open w failed\n");
    } else {
        fprintf(fp, "Lan 1\n");
        fclose(fp);

        // 2) Ghi thêm bằng "a"
        fp = fopen(path, "a");
        if (!fp) {
            printf("open a failed\n");
        } else {
            fprintf(fp, "Lan 2 (append)\n");
            fclose(fp);

            // 3) Đọc lại để xem kết quả
            fp = fopen(path, "r");
            if (!fp) {
                printf("open r failed\n");
            } else {
                char line[64];
                printf("Noi dung file:\n");
                while (fgets(line, sizeof(line), fp)) {
                    printf("%s", line);
                }
                fclose(fp);
            }
        }
    }
    return 0;
}

# %% [markdown]
# #### Ví dụ 3 — Đọc file theo dòng bằng `fgets` (loop đúng)
# - Mục tiêu: pattern chuẩn: `while (fgets(...))`.

# %%
#include <stdio.h>

int main(void) {
    const char* path = "ch12_ex3.txt";

    // Tạo file mẫu
    FILE* fp = fopen(path, "w");
    if (!fp) {
        printf("open w failed\n");
    } else {
        fprintf(fp, "AAA\nBBB\nCCC\n");
        fclose(fp);

        // Đọc file
        fp = fopen(path, "r");
        if (!fp) {
            printf("open r failed\n");
        } else {
            char line[64];
            int lineNo = 0;
            while (fgets(line, sizeof(line), fp)) {
                lineNo++;
                printf("%d: %s", lineNo, line);
            }
            fclose(fp);
        }
    }
    return 0;
}

# %% [markdown]
# #### Ví dụ 4 — Binary I/O cơ bản (`fwrite`/`fread`)
# - Mục tiêu: nhớ mode `wb/rb` và cách ghi/đọc dữ liệu nhị phân.

# %%
#include <stdio.h>

int main(void) {
    const char* path = "ch12_ex4.bin";

    int a[3] = {10, 20, 30};

    FILE* fp = fopen(path, "wb");
    if (!fp) {
        printf("open wb failed\n");
    } else {
        fwrite(a, sizeof(int), 3, fp);
        fclose(fp);

        int b[3] = {0};
        fp = fopen(path, "rb");
        if (!fp) {
            printf("open rb failed\n");
        } else {
            fread(b, sizeof(int), 3, fp);
            fclose(fp);

            printf("Read back: %d %d %d\n", b[0], b[1], b[2]);
        }
    }
    return 0;
}

# %% [markdown]
# ### Luyện tập
# 1. Mở file `data.bin` ở chế độ nhị phân và ghi 100 số nguyên.
# 2. Mở file `log.txt` ở chế độ append và ghi thêm một dòng.
# 3. Nếu `fopen` trả về `NULL` thì bạn nên làm gì?
#
# <details>
# <summary>Solution</summary>
#
# Gợi ý:
# - Dùng mode `"wb"` cho ghi nhị phân, `fwrite` để ghi mảng.
# - Mode append: `"a"`.
# - Kiểm tra lỗi và kết thúc hoặc thông báo.
# </details>

# %% [markdown]
# ### Lỗi thường gặp
# - Không kiểm tra `NULL` khi mở file.
# - Quên `fclose`, gây rò rỉ tài nguyên.
# - Dùng sai mode (`"w"` làm mất dữ liệu cũ).
#
# ### Tóm tắt
# - `FILE` là kiểu đại diện luồng tệp; `FILE*` là con trỏ tới luồng.
# - `fopen` mở file, `fclose` đóng file.
# - Chọn đúng mode cho đọc/ghi và văn bản/nhị phân.
#
# ### Checkpoint quiz
# 1. `fopen` trả về gì khi mở thất bại?
# 2. Mode nào để vừa đọc vừa ghi và ghi đè nội dung cũ?
# 3. Tại sao nên `fclose` sau khi dùng?
#
# <details>
# <summary>Đáp án</summary>
#
# 1. `NULL`.
# 2. `"w+"`.
# 3. Để giải phóng tài nguyên và đảm bảo dữ liệu được ghi hết.
# </details>

# %% [markdown]
# <a id="ch13"></a>
# ## Chương 13. Toán tử bit
#
# **Prerequisites**
# - Chương 3 (toán tử).
#
# **Learning outcomes**
# - Phân biệt bitwise và logical: `&` vs `&&`, `|` vs `||`.
# - Dùng dịch bit để tạo mask: `(1u << k)`.
# - Thuộc công thức bitmask: set/clear/toggle/test.
# - Nhận biết bẫy ưu tiên toán tử trong biểu thức bit.
#
# ### Giải thích
#
# #### 1) Bitwise vs logical
# - Bitwise `& | ^ ~` làm việc trên **từng bit**.
# - Logical `&& || !` làm việc trên **đúng/sai** và có short-circuit.
#
# Bẫy: dùng `&` trong `if` tưởng là `&&`.
#
# #### 2) Dịch bit (shift) và mask
# - `(1u << k)` tạo mask có bit k = 1.
# - Nên dùng `unsigned` (`1u`) để tránh bẫy số âm.
#
# #### 3) Công thức bitmask (cực hay thi)
# Giả sử `mask = 1u << k`:
# - Set bit k: `x |= mask`
# - Clear bit k: `x &= ~mask`
# - Toggle bit k: `x ^= mask`
# - Test bit k: `(x & mask) != 0`
#
# Bẫy precedence:
# - Viết `(x & mask) == 0` nên có ngoặc.
# - `x & mask == 0` bị hiểu sai thành `x & (mask == 0)`.
#
# #### 4) XOR (optional)
# - `a ^ a = 0`
# - XOR swap có thể xuất hiện trong lý thuyết nhưng không khuyến khích viết thực tế.
#
# ### Ví dụ
#
# #### Ví dụ 1 — Test / set / clear / toggle một bit
# - Mục tiêu: thuộc 4 công thức bitmask.

# %%
#include <stdio.h>

int main(void) {
    unsigned int x = 0u;
    unsigned int k = 3u;
    unsigned int mask = 1u << k;

    printf("Ban dau: x = 0x%X\n", x);

    // Set bit k
    x |= mask;
    printf("Sau set: x = 0x%X\n", x);

    // Test bit k
    printf("Test bit %u: %s\n", k, ((x & mask) != 0u) ? "ON" : "OFF");

    // Toggle bit k
    x ^= mask;
    printf("Sau toggle: x = 0x%X\n", x);

    // Clear bit k
    x &= ~mask;
    printf("Sau clear: x = 0x%X\n", x);
    return 0;
}

# %% [markdown]
# #### Ví dụ 2 — Dịch bit để tạo mask
# - Mục tiêu: nhớ `(1u << k)`.

# %%
#include <stdio.h>

int main(void) {
    unsigned int k = 5u;
    unsigned int mask = 1u << k;

    printf("k=%u => mask=0x%X\n", k, mask);

    // Bẫy: 1 << 31 (int) có thể overflow; dùng 1u để an toàn hơn.
    return 0;
}

# %% [markdown]
# #### Ví dụ 3 — Bẫy precedence: `x & mask == 0`
# - Mục tiêu: thấy sự khác nhau giữa biểu thức sai và đúng.

# %%
#include <stdio.h>

int main(void) {
    unsigned int x = 1u;   // 0b...0001
    unsigned int mask = 2u; // 0b...0010

    // SAI: bị hiểu thành x & (mask == 0)
    unsigned int wrong = x & mask == 0u;

    // ĐÚNG: test bit bằng cách ngoặc rõ ràng
    unsigned int correct = ((x & mask) == 0u);

    printf("wrong   = %u\n", wrong);
    printf("correct = %u\n", correct);
    return 0;
}

# %% [markdown]
# #### Ví dụ 4 — XOR demo (optional)
# - Mục tiêu: hiểu XOR: bit khác nhau → 1, giống nhau → 0.

# %%
#include <stdio.h>

int main(void) {
    unsigned int a = 5u; // 0101
    unsigned int b = 3u; // 0011

    printf("a^b = %u (0x%X)\n", a ^ b, a ^ b);
    printf("a^a = %u\n", a ^ a);
    return 0;
}

# %% [markdown]
# ### Luyện tập
# 1. Tính `x >> 2` và `x << 1` với `x = 12` (1100₂).
# 2. Dùng XOR để tìm phần tử xuất hiện lẻ số lần trong mảng `{1,2,1,2,3,2,2}`.
# 3. Phân biệt `&` (bitwise) với `&&` (logic).
#
# <details>
# <summary>Solution</summary>
#
# Gợi ý:
# - `12 >> 2` là 3, `12 << 1` là 24.
# - Duyệt mảng và XOR tất cả phần tử.
# - `&` làm việc theo bit, `&&` trả về 0/1 theo điều kiện.
# </details>

# %% [markdown]
# ### Lỗi thường gặp
# - Nhầm `&` với `&&`.
# - Dùng dịch bit với số âm gây kết quả không xác định.
# - Dịch vượt quá số bit của kiểu dữ liệu.
#
# ### Tóm tắt
# - Toán tử bit thao tác trực tiếp trên bit.
# - Dịch trái gần giống nhân 2^n, dịch phải gần giống chia 2^n (với số dương).
# - Cẩn thận với kiểu dữ liệu và giá trị âm.
#
# ### Checkpoint quiz
# 1. `x ^ x` luôn bằng bao nhiêu?
# 2. Toán tử nào đảo tất cả bit?
# 3. `1 << 3` bằng bao nhiêu?
#
# <details>
# <summary>Đáp án</summary>
#
# 1. 0.
# 2. `~`.
# 3. 8.
# </details>

# %% [markdown]
# <a id="ch14"></a>
# ## Chương 14. C++ cơ bản
#
# **Prerequisites**
# - Chương 5 (hàm).
# - Chương 7 (con trỏ — để so sánh với reference).
#
# **Learning outcomes**
# - Dùng `std::cout`/`std::cin` với toán tử `<<`/`>>`.
# - Dùng `std::string` và `std::getline` (đặc biệt: tên có khoảng trắng).
# - Phân biệt **reference** (`&`) và **pointer** (`*`).
# - Hiểu nạp chồng hàm (overload) và bẫy đối số mặc định.
# - Biết chữ ký “đẹp” khi truyền chuỗi: `const std::string&`.
#
# ### Giải thích
#
# #### 1) `cout/cin` và toán tử `<< >>`
# - `std::cout << ...` để in.
# - `std::cin >> ...` để đọc theo **token** (bỏ qua khoảng trắng).
#
# Bẫy:
# - `std::endl` vừa xuống dòng vừa flush (thường chậm hơn `"\n"`).
#
# #### 2) `std::string` và `getline`
# - `std::string` quản lý bộ nhớ tự động.
# - `std::getline(cin, s)` đọc **cả dòng** (giữ khoảng trắng).
#
# Bẫy kinh điển:
# - Đọc số bằng `cin >> x` xong gọi `getline` ngay → `getline` có thể đọc trúng `\n` còn lại và ra chuỗi rỗng.
# - Cách xử lý: dùng `std::ws` hoặc `cin.ignore(...)` trước `getline`.
#
# #### 3) Reference (`&`) khác pointer (`*`) như thế nào?
# - Reference là **bí danh** của một biến (không NULL, phải gắn ngay khi khai báo).
# - Pointer là biến lưu **địa chỉ** (có thể NULL, có thể đổi trỏ).
#
# Ứng dụng hay gặp: swap bằng reference.
#
# #### 4) Overload và default arguments
# - Overload: cùng tên nhưng khác tham số.
# - Default args có thể làm đề “gài” hàm nào được gọi.
#
# ### Ví dụ
#
# #### Ví dụ 1 — Bẫy `cin >>` rồi `getline` (và cách sửa)
# - Mục tiêu: nhìn kết quả để nhớ phải xử lý newline.
# - Để ví dụ chạy ổn định trong notebook, ta mô phỏng `cin` bằng `std::istringstream`.

# %%
#include <iostream>
#include <sstream>
#include <string>

int main() {
    std::istringstream in("20\nNguyen Van A\n");

    int age;
    std::string name;

    in >> age;

    // SAI: getline đọc ngay ký tự '\n' còn lại => chuỗi rỗng
    std::getline(in, name);
    std::cout << "(wrong) age=" << age << ", name='" << name << "'\n";

    // ĐÚNG: dùng std::ws để bỏ whitespace (bao gồm '\n') trước khi getline
    in.clear();
    in.seekg(0);
    in >> age;
    std::getline(in >> std::ws, name);

    std::cout << "(right) age=" << age << ", name='" << name << "'\n";
    return 0;
}

# %% [markdown]
# #### Ví dụ 2 — Swap bằng reference
# - Mục tiêu: thấy reference là alias → đổi được biến gốc.

# %%
#include <iostream>

void swap_ref(int& a, int& b);

int main() {
    int x = 1;
    int y = 2;

    std::cout << "Before: x=" << x << " y=" << y << "\n";
    swap_ref(x, y);
    std::cout << "After : x=" << x << " y=" << y << "\n";
    return 0;
}

#ifndef CH14_EX2_SWAP_DEFINED
#define CH14_EX2_SWAP_DEFINED
void swap_ref(int& a, int& b) {
    int tmp = a;
    a = b;
    b = tmp;
}
#endif

# %% [markdown]
# #### Ví dụ 3 — Overload resolution (hàm nào được gọi?)
# - Mục tiêu: mô phỏng kiểu câu hỏi “gọi hàm nào” trong đề.

# %%
#include <iostream>

void show_overload(int x);
void show_overload(double x);

int main() {
    show_overload(10);     // gọi bản int
    show_overload(3.14);   // gọi bản double
    show_overload('A');    // 'A' là char, thường được nâng lên int
    return 0;
}

#ifndef CH14_EX3_OVERLOAD_DEFINED
#define CH14_EX3_OVERLOAD_DEFINED
void show_overload(int x) {
    std::cout << "show_overload(int): " << x << "\n";
}

void show_overload(double x) {
    std::cout << "show_overload(double): " << x << "\n";
}
#endif

# %% [markdown]
# #### Ví dụ 4 — Truyền chuỗi kiểu `const std::string&` (không copy)
# - Mục tiêu: nhận diện chữ ký hay gặp trong đề và trong code chuẩn.

# %%
#include <iostream>
#include <string>

void print_name(const std::string& s);

int main() {
    std::string name = "Lan";
    print_name(name);
    return 0;
}

#ifndef CH14_EX4_CONSTREF_DEFINED
#define CH14_EX4_CONSTREF_DEFINED
void print_name(const std::string& s) {
    std::cout << "Hello, " << s << "\n";
}
#endif

# %% [markdown]
# ### Luyện tập
# 1. Viết hàm `swap(double &a, double &b)` dùng tham chiếu để hoán đổi.
# 2. Tạo hai hàm `sum(int a, int b)` và `sum(int a, int b, int c)`.
# 3. Dùng `std::string` nối họ và tên, in ra kết quả.
#
# <details>
# <summary>Solution</summary>
#
# Gợi ý:
# - Dùng biến tạm khi swap.
# - Nạp chồng theo số lượng tham số.
# - Nối chuỗi bằng `+`.
# </details>

# %% [markdown]
# ### Lỗi thường gặp
# - Quên `std::` hoặc không `using namespace std;`.
# - Nhầm tham chiếu với con trỏ.
# - Nạp chồng chỉ khác kiểu trả về (không hợp lệ).
#
# ### Tóm tắt
# - `iostream` và `std::string` là nền tảng nhập/xuất C++.
# - Tham chiếu là bí danh cho biến.
# - Nạp chồng giúp dùng cùng tên cho nhiều chữ ký hàm.
#
# ### Checkpoint quiz
# 1. Tham chiếu có thể trỏ sang biến khác sau khi khởi tạo không?
# 2. Điều kiện để hai hàm được nạp chồng?
# 3. `std::string` khác chuỗi C ở điểm nào?
#
# <details>
# <summary>Đáp án</summary>
#
# 1. Không.
# 2. Khác số lượng hoặc kiểu tham số.
# 3. `std::string` quản lý bộ nhớ tự động và an toàn hơn.
# </details>

# %% [markdown]
# <a id="ch15"></a>
# ## Chương 15. Lớp, constructor, destructor
#
# **Prerequisites**
# - Chương 14.
#
# **Learning outcomes**
# - Viết class đúng tinh thần đóng gói: `private` dữ liệu, `public` hành vi.
# - Hiểu constructor/initializer list và bẫy thứ tự khởi tạo member.
# - Hiểu destructor chạy khi nào (object stack vs heap).
# - Biết `const` member function và vì sao cần.
#
# ### Giải thích
#
# #### 1) Encapsulation (đóng gói)
# - Dữ liệu quan trọng để `private`.
# - Chỉ mở `public` những thao tác cần thiết.
#
# #### 2) Constructor và initializer list
# - Constructor giúp object ở trạng thái hợp lệ ngay khi tạo.
# - Initializer list chạy trước thân constructor.
#
# Bẫy thi hay gặp:
# - Thứ tự khởi tạo member theo **thứ tự khai báo trong class**, không theo thứ tự trong initializer list.
#
# #### 3) Destructor chạy khi nào?
# - Object tạo trên stack: destructor chạy khi ra khỏi scope.
# - Object tạo bằng `new`: destructor chỉ chạy khi `delete`.
#
# #### 4) `const` member function
# - `double area() const` đảm bảo hàm không sửa trạng thái.
# - Nếu thiếu `const`, bạn không gọi được trên object `const`.
#
# ### Ví dụ
#
# #### Ví dụ 1 — Class Rectangle: init list + `const` method
# - Mục tiêu: form class chuẩn + dùng `area() const`.

# %%
#include <iostream>

#ifndef CH15_RECT_DEFINED
#define CH15_RECT_DEFINED
class Rect15 {
private:
    double w;
    double h;

public:
    Rect15(double width, double height) : w(width), h(height) {}

    double area() const {
        return w * h;
    }
};
#endif

int main() {
    Rect15 r(3.0, 4.0);
    std::cout << "area = " << r.area() << "\n";
    return 0;
}

# %% [markdown]
# #### Ví dụ 2 — Thứ tự ctor/dtor theo scope (in log để nhớ)
# - Mục tiêu: thấy destructor chạy theo thứ tự ngược với constructor.

# %%
#include <iostream>

#ifndef CH15_TRACE_DEFINED
#define CH15_TRACE_DEFINED
struct Trace15 {
    const char* name;
    Trace15(const char* n) : name(n) { std::cout << "ctor " << name << "\n"; }
    ~Trace15() { std::cout << "dtor " << name << "\n"; }
};
#endif

int main() {
    Trace15 a("A");
    {
        Trace15 b("B");
        Trace15 c("C");
        std::cout << "-- inside inner scope --\n";
    }
    std::cout << "-- back to outer scope --\n";
    return 0;
}

# %% [markdown]
# #### Ví dụ 3 — Heap vs stack: destructor chỉ chạy khi `delete`
# - Mục tiêu: nhớ bẫy: tạo bằng `new` mà quên `delete` → leak và dtor không chạy.

# %%
#include <iostream>

#ifndef CH15_TRACE2_DEFINED
#define CH15_TRACE2_DEFINED
struct Trace15b {
    const char* name;
    Trace15b(const char* n) : name(n) { std::cout << "ctor " << name << "\n"; }
    ~Trace15b() { std::cout << "dtor " << name << "\n"; }
};
#endif

int main() {
    Trace15b onStack("stack");

    Trace15b* onHeap = new Trace15b("heap");

    std::cout << "-- deleting heap object --\n";
    delete onHeap;

    std::cout << "-- end of cell scope --\n";
    // onStack sẽ tự dtor khi ra khỏi scope
    return 0;
}

# %% [markdown]
# ### Luyện tập
# 1. Viết lớp `Point` với constructor nhận `x, y` và hàm `print()`.
# 2. Tạo lớp `Counter` có constructor đặt `count=0` và hàm `inc()`.
# 3. Thứ tự gọi destructor của 3 đối tượng cục bộ là như thế nào?
#
# <details>
# <summary>Solution</summary>
#
# Gợi ý:
# - Destructor gọi theo thứ tự ngược với constructor.
# - `Counter` tăng `count` trong `inc()`.
# </details>

# %% [markdown]
# ### Lỗi thường gặp
# - Quên đặt `public` cho các hàm cần dùng ngoài lớp.
# - Không khởi tạo thành viên trong constructor.
# - Hiểu sai thứ tự gọi destructor.
#
# ### Tóm tắt
# - Lớp đóng gói dữ liệu và hành vi.
# - Constructor khởi tạo đối tượng, destructor giải phóng tài nguyên.
# - Destructor chạy theo thứ tự ngược tạo đối tượng.
#
# ### Checkpoint quiz
# 1. Thành viên `private` có truy cập trực tiếp từ `main` được không?
# 2. Khi nào destructor của đối tượng cục bộ được gọi?
# 3. Có thể có nhiều constructor không?
#
# <details>
# <summary>Đáp án</summary>
#
# 1. Không.
# 2. Khi ra khỏi phạm vi (scope).
# 3. Có, thông qua nạp chồng.
# </details>

# %% [markdown]
# <a id="ch16"></a>
# ## Chương 16. new/delete và RAII
#
# **Prerequisites**
# - Chương 10 (malloc/free để so sánh).
# - Chương 15 (constructor/destructor).
#
# **Learning outcomes**
# - Phân biệt `new/delete` với `malloc/free` (new gọi ctor, delete gọi dtor).
# - Nhớ cặp đúng: `new[]` đi với `delete[]`.
# - Hiểu bản chất RAII: tài nguyên gắn với lifetime của object.
# - Dùng `std::unique_ptr` để tránh quên `delete`.
#
# ### Giải thích
#
# #### 1) `new/delete` vs `malloc/free`
# - `new T(...)` vừa cấp phát vừa khởi tạo (gọi constructor).
# - `delete p` giải phóng và gọi destructor.
#
# Không được trộn:
# - `new` với `free`, hoặc `malloc` với `delete`.
#
# #### 2) `new[]/delete[]`
# - Mảng cấp phát bằng `new[]` phải giải phóng bằng `delete[]`.
# - Dùng sai cặp → undefined behavior (bẫy thi hay hỏi đúng/sai).
#
# #### 3) RAII
# RAII = Resource Acquisition Is Initialization:
# - Tài nguyên (bộ nhớ, file, mutex, …) được “bọc” bởi một object.
# - Khi object ra khỏi scope, destructor chạy và tự giải phóng.
#
# #### 4) Smart pointer: `unique_ptr`
# - `unique_ptr` sở hữu duy nhất.
# - Không copy được, chỉ move được.
#
# ### Ví dụ
#
# #### Ví dụ 1 — `new/delete` cơ bản
# - Mục tiêu: nhớ `delete` giải phóng đúng, và không dùng lại sau delete.

# %%
#include <iostream>

int main() {
    int* p = new int(10);
    std::cout << "*p = " << *p << "\n";

    delete p;
    p = nullptr;

    // DANG SAI (comment): dùng sau delete
    //std::cout << *p << "\n";
    return 0;
}

# %% [markdown]
# #### Ví dụ 2 — `new[]/delete[]` (đúng cặp)
# - Mục tiêu: chốt bẫy thi: mảng phải `delete[]`.

# %%
#include <iostream>

int main() {
    int* a = new int[3]{1, 2, 3};

    std::cout << a[0] << " " << a[1] << " " << a[2] << "\n";

    delete[] a;
    return 0;
}

# %% [markdown]
# #### Ví dụ 3 — `unique_ptr` (RAII) thay cho `new/delete`
# - Mục tiêu: tự giải phóng khi ra khỏi scope.

# %%
#include <iostream>
#include <memory>

int main() {
    auto p = std::make_unique<int>(42);
    std::cout << "*p = " << *p << "\n";

    // Bẫy: unique_ptr không copy được (comment)
    //auto q = p;

    auto q = std::move(p); // move thì được
    std::cout << "*q = " << *q << "\n";
    return 0;
}

# %% [markdown]
# #### Ví dụ 4 — (Optional) `unique_ptr` với custom deleter cho `FILE*`
# - Mục tiêu: nối với Chương 12: quên `fclose` là bẫy thường gặp.
# - Ý tưởng: dùng RAII để tự đóng file khi ra khỏi scope.

# %%
#include <cstdio>
#include <memory>

int main() {
    const char* path = "ch16_file.txt";

    std::unique_ptr<FILE, decltype(&fclose)> fp(fopen(path, "w"), &fclose);
    if (!fp) {
        printf("fopen failed\n");
    } else {
        fprintf(fp.get(), "Hello from RAII file!\n");

        // Không cần gọi fclose thủ công: fp ra khỏi scope sẽ tự fclose.
        printf("Wrote %s\n", path);
    }
    return 0;
}

# %% [markdown]
# ### Luyện tập
# 1. Cấp phát mảng `int` 5 phần tử bằng `new[]`, gán giá trị, rồi giải phóng.
# 2. Sửa lỗi trong đoạn mã: `double *a = new double[3]; ... delete a;`.
# 3. Giải thích vì sao RAII giúp tránh rò rỉ tài nguyên.
#
# <details>
# <summary>Solution</summary>
#
# Gợi ý:
# - Dùng `delete[]`.
# - RAII đảm bảo destructor luôn chạy khi ra khỏi scope.
# </details>

# %% [markdown]
# ### Lỗi thường gặp
# - Dùng `delete` thay vì `delete[]`.
# - Quên giải phóng khi dùng `new`.
# - Trộn `malloc/free` với `new/delete`.
#
# ### Tóm tắt
# - `new/delete` quản lý bộ nhớ trong C++.
# - Mảng dùng `new[]/delete[]`.
# - RAII giúp quản lý tài nguyên an toàn.
#
# ### Checkpoint quiz
# 1. `new` khác `malloc` ở điểm nào?
# 2. `unique_ptr` giải phóng tài nguyên khi nào?
# 3. Vì sao không nên trộn `malloc` với `delete`?
#
# <details>
# <summary>Đáp án</summary>
#
# 1. `new` gọi constructor và trả về kiểu đúng.
# 2. Khi đối tượng `unique_ptr` ra khỏi scope.
# 3. Vì cơ chế cấp phát/giải phóng không tương thích.
# </details>

# %% [markdown]
# <a id="ch17"></a>
# ## Chương 17. Kế thừa và đa hình
#
# **Prerequisites**
# - Chương 15 (class).
# - Chương 16 (new/delete).
#
# **Learning outcomes**
# - Hiểu quan hệ kế thừa (is-a) và cú pháp `class D : public B`.
# - Hiểu `virtual` tạo đa hình động (runtime dispatch) khi gọi qua base pointer/reference.
# - Phân biệt override vs overload (signature lệch là bẫy).
# - Biết vì sao cần **virtual destructor** khi xóa qua base pointer.
# - Nhận biết object slicing khi gán derived vào base by value.
#
# ### Giải thích
#
# #### 1) Kế thừa (inheritance)
# - `public` inheritance thể hiện quan hệ “D is-a B”.
#
# #### 2) `virtual` và dynamic dispatch
# - Nếu hàm base là `virtual` và derived override đúng signature, thì gọi qua `Base*` sẽ chạy phiên bản derived.
#
# Bẫy:
# - Quên `virtual` → gọi base.
# - Signature lệch (khác `const`, khác tham số) → không override, chỉ overload.
#
# #### 3) Virtual destructor
# Nếu class có virtual method (đa hình), base destructor nên `virtual`.
# - Nếu không, `delete basePtr` có thể không gọi destructor của derived (bẫy thi rất hay).
#
# #### 4) Object slicing
# - `Base b = Derived();` làm “cắt” phần derived.
# - Đa hình chỉ hoạt động khi dùng pointer/reference.
#
# ### Ví dụ
#
# #### Ví dụ 1 — Virtual dispatch qua `Base*`
# - Mục tiêu: câu đề kinh điển: `Base* p = new D; p->f();`.

# %%
#include <iostream>

#ifndef CH17_EX1_DEFINED
#define CH17_EX1_DEFINED
struct Base17 {
    virtual int f() { return 1; }
    virtual ~Base17() = default;
};

struct D17 : Base17 {
    int f() override { return 2; }
};
#endif

int main() {
    Base17* p = new D17();
    std::cout << "p->f() = " << p->f() << "\n";
    delete p;
    return 0;
}

# %% [markdown]
# #### Ví dụ 2 — Override vs overload (signature lệch)
# - Mục tiêu: bẫy thi: khác `const`/tham số => không override.
# - Mẹo: dùng từ khóa `override` để compiler bắt lỗi.

# %%
#include <iostream>

#ifndef CH17_EX2_DEFINED
#define CH17_EX2_DEFINED
struct Base17b {
    virtual int g() const { return 10; }
    virtual ~Base17b() = default;
};

struct D17b : Base17b {
    // KHONG override vì thiếu const (đây là overload/hiding)
    int g() { return 20; }

    // Nếu viết: int g() override { ... } thì compiler sẽ báo lỗi (tốt!).
};
#endif

int main() {
    D17b d;

    Base17b* p = &d;
    std::cout << "Base* calls g() const -> " << p->g() << "\n";

    // Gọi trực tiếp bằng object D17b sẽ gọi bản không-const
    std::cout << "D object calls g() -> " << d.g() << "\n";
    return 0;
}

# %% [markdown]
# #### Ví dụ 3 — Virtual destructor: delete qua base pointer
# - Mục tiêu: thấy thứ tự destructor: ~Derived rồi ~Base.

# %%
#include <iostream>

#ifndef CH17_EX3_DEFINED
#define CH17_EX3_DEFINED
struct Base17c {
    virtual ~Base17c() { std::cout << "~Base\n"; }
};

struct D17c : Base17c {
    ~D17c() override { std::cout << "~Derived\n"; }
};
#endif

int main() {
    Base17c* p = new D17c();
    delete p; // phải gọi ~Derived rồi ~Base
    return 0;
}

# %% [markdown]
# #### Ví dụ 4 — Object slicing (mất đa hình khi copy by value)
# - Mục tiêu: nhớ: đa hình cần pointer/reference.

# %%
#include <iostream>

#ifndef CH17_EX4_DEFINED
#define CH17_EX4_DEFINED
struct Base17d {
    virtual int f() { return 1; }
    virtual ~Base17d() = default;
};

struct D17d : Base17d {
    int f() override { return 2; }
};
#endif

int main() {
    D17d d;

    Base17d b = d; // slicing: phần derived bị cắt
    std::cout << "b.f() = " << b.f() << " (khong con 2)\n";

    Base17d& ref = d;
    std::cout << "ref.f() = " << ref.f() << " (da hinh)\n";
    return 0;
}

# %% [markdown]
# ### Luyện tập
# 1. Tạo lớp `Animal` có hàm ảo `sound()`, lớp `Dog` ghi đè.
# 2. Điều gì xảy ra nếu destructor của lớp cơ sở không `virtual`?
# 3. Nêu sự khác nhau giữa đa hình tĩnh và đa hình động.
#
# <details>
# <summary>Solution</summary>
#
# Gợi ý:
# - Dùng `virtual void sound() const`.
# - Có thể không gọi destructor của lớp dẫn xuất, gây rò rỉ.
# - Đa hình tĩnh là nạp chồng, động là `virtual`.
# </details>

# %% [markdown]
# ### Lỗi thường gặp
# - Quên `virtual` nên không có đa hình động.
# - Quên `override` làm dễ sai chữ ký.
# - Quên destructor ảo trong lớp cơ sở.
#
# ### Tóm tắt
# - Kế thừa giúp tái sử dụng code.
# - `virtual` kích hoạt đa hình động.
# - Destructor ảo giúp giải phóng đúng lớp dẫn xuất.
#
# ### Checkpoint quiz
# 1. Khi gọi `basePtr->func()` thì phiên bản nào chạy nếu `func` là `virtual`?
# 2. Từ khóa nào dùng để ghi đè rõ ràng?
# 3. Vì sao cần destructor ảo?
#
# <details>
# <summary>Đáp án</summary>
#
# 1. Phiên bản của lớp dẫn xuất (nếu có override).
# 2. `override`.
# 3. Đảm bảo gọi destructor đúng khi xóa qua con trỏ cơ sở.
# </details>

# %% [markdown]
# <a id="ch18"></a>
# ## Chương 18. Template và STL
#
# **Prerequisites**
# - Chương 14 (C++ cơ bản).
#
# **Learning outcomes**
# - Hiểu function template và type deduction.
# - Dùng `std::vector`: `size`, `capacity`, `push_back` (và bẫy invalidation ở mức cơ bản).
# - Dùng `std::map`: `find` vs `operator[]` (bẫy: `[]` có side-effect).
# - Biết `std::sort` cho vector.
#
# ### Giải thích
#
# #### 1) Function template
# Template giúp viết 1 hàm dùng cho nhiều kiểu:
# - `template<typename T> T maxValue(T a, T b)`.
#
# Bẫy: so sánh `std::string` là so theo thứ tự từ điển (lexicographic).
#
# #### 2) `std::vector`
# - `vector` là “mảng động” an toàn.
# - `size()` là số phần tử đang có.
# - `capacity()` là dung lượng đã cấp phát.
#
# Bẫy mức thi:
# - `push_back` có thể làm tăng capacity và làm iterator/pointer cũ bị invalid.
#
# #### 3) `std::map`
# - map lưu cặp (key, value).
# - `m.find(k)` để kiểm tra tồn tại.
#
# Bẫy cực hay:
# - `m[k]` sẽ **tạo phần tử mới** nếu key chưa tồn tại.
#
# #### 4) `std::sort`
# - `std::sort(v.begin(), v.end())`.
# - Nhớ `#include <algorithm>`.
#
# ### Ví dụ
#
# #### Ví dụ 1 — Template `maxValue`
# - Mục tiêu: thấy 1 template dùng được cho int/double/string.

# %%
#include <iostream>
#include <string>

// Guard để chạy lại cell không bị redefinition
#ifndef CH18_MAX_TEMPLATE_DEFINED
#define CH18_MAX_TEMPLATE_DEFINED

template <typename T>
T maxValue(T a, T b) {
    return (a > b) ? a : b;
}

#endif

int main() {
    std::cout << maxValue(3, 5) << "\n";
    std::cout << maxValue(2.5, 1.2) << "\n";
    std::cout << maxValue(std::string("apple"), std::string("banana")) << "\n";
    return 0;
}

# %% [markdown]
# #### Ví dụ 2 — `vector`: size vs capacity
# - Mục tiêu: thấy capacity tăng theo từng bước.

# %%
#include <iostream>
#include <vector>

int main() {
    std::vector<int> v;

    for (int i = 1; i <= 8; i++) {
        v.push_back(i);
        std::cout << "push " << i << ": size=" << v.size() << " cap=" << v.capacity() << "\n";
    }

    // Nếu giữ iterator/pointer tới phần tử, push_back có thể làm nó bị invalid.
    return 0;
}

# %% [markdown]
# #### Ví dụ 3 — `sort` vector
# - Mục tiêu: pattern thi: sort rồi in.

# %%
#include <algorithm>
#include <iostream>
#include <vector>

int main() {
    std::vector<int> v = {5, 1, 4, 2, 3};

    std::cout << "Before: ";
    for (int x : v) std::cout << x << " ";
    std::cout << "\n";

    std::sort(v.begin(), v.end());

    std::cout << "After : ";
    for (int x : v) std::cout << x << " ";
    std::cout << "\n";
    return 0;
}

# %% [markdown]
# #### Ví dụ 4 — `map`: `find` vs `operator[]` (bẫy side-effect)
# - Mục tiêu: thấy `m[key]` có thể tạo phần tử mới.

# %%
#include <iostream>
#include <map>
#include <string>

int main() {
    std::map<std::string, int> m;

    std::cout << "size(before) = " << m.size() << "\n";

    // operator[] sẽ tạo key "apple" với value mặc định 0, rồi mới ++
    m["apple"]++;

    std::cout << "size(after)  = " << m.size() << "\n";
    std::cout << "apple count  = " << m["apple"] << "\n";

    // Nếu chỉ muốn check tồn tại mà không tạo, dùng find:
    if (m.find("banana") == m.end()) {
        std::cout << "banana not found\n";
    }
    return 0;
}

# %% [markdown]
# ### Luyện tập
# 1. Viết hàm template `minValue` nhận hai giá trị và trả về nhỏ hơn.
# 2. Dùng `std::vector<double>` để tính trung bình cộng.
# 3. Dùng `std::map<std::string,int>` đếm số lần xuất hiện của mỗi từ trong một câu.
#
# <details>
# <summary>Solution</summary>
#
# Gợi ý:
# - Cú pháp template tương tự `maxValue`.
# - Duyệt vector để tính `sum`.
# - Tách từ và tăng đếm trong `map`.
# </details>

# %% [markdown]
# ### Lỗi thường gặp
# - Quên `#include <vector>` hoặc `<map>`.
# - Nhầm `std::vector` với mảng C.
# - Không chỉ rõ namespace `std`.
#
# ### Tóm tắt
# - Template giúp viết hàm tổng quát.
# - `vector` và `map` là cấu trúc dữ liệu mạnh trong STL.
# - Dùng vòng lặp hoặc range-for để duyệt `vector`.
#
# ### Checkpoint quiz
# 1. `std::vector` có tự quản lý bộ nhớ không?
# 2. `std::map` lưu cặp gì?
# 3. Template giúp giảm điều gì trong code?
#
# <details>
# <summary>Đáp án</summary>
#
# 1. Có.
# 2. Cặp khóa–giá trị.
# 3. Trùng lặp code cho nhiều kiểu.
# </details>

# %% [markdown]
# <a id="ch19"></a>
# ## Chương 19. File I/O trong C++
#
# **Prerequisites**
# - Chương 14 (iostream/string).
# - Chương 16 (RAII).
#
# **Learning outcomes**
# - Dùng `std::ifstream`/`std::ofstream`/`std::fstream` để đọc/ghi file.
# - Check trạng thái stream (`if (!in)`, `is_open()`).
# - Phân biệt đọc token (`>>`) và đọc dòng (`getline`).
# - Dùng mode `std::ios::app` và `std::ios::binary`.
# - Hiểu RAII: file tự đóng khi object ra khỏi scope.
#
# ### Giải thích
#
# #### 1) Stream file trong C++
# - `std::ifstream`: đọc.
# - `std::ofstream`: ghi.
# - `std::fstream`: đọc/ghi.
#
# Luôn kiểm tra mở file:
# - `if (!in)` hoặc `if (!in.is_open())`.
#
# #### 2) `>>` vs `getline`
# - `>>` đọc theo token (bỏ whitespace).
# - `getline` đọc cả dòng (giữ khoảng trắng).
#
# Bẫy newline giống Chương 14 khi trộn `>>` và `getline`.
#
# #### 3) Mode
# - `std::ios::app`: append.
# - `std::ios::binary`: nhị phân.
#
# #### 4) RAII auto-close
# Object stream ra khỏi scope sẽ tự đóng file.
#
# ### Ví dụ
#
# #### Ví dụ 1 — Copy file line-by-line (`getline` loop)
# - Mục tiêu: pattern thực tế: while(getline(in,line)).

# %%
#include <fstream>
#include <iostream>
#include <string>

int main() {
    const char* inPath = "ch19_input.txt";
    const char* outPath = "ch19_output.txt";

    // Tạo file input mẫu
    {
        std::ofstream tmp(inPath);
        tmp << "Line 1\nLine 2\nLine 3\n";
    }

    std::ifstream in(inPath);
    std::ofstream out(outPath);

    if (!in || !out) {
        std::cerr << "Khong mo duoc file\n";
    } else {
        std::string line;
        while (std::getline(in, line)) {
            out << line << "\n";
        }

        std::cout << "Copied to " << outPath << "\n";
    }
    return 0;
}

# %% [markdown]
# #### Ví dụ 2 — Đọc số và tính tổng (`while(in >> x)`)
# - Mục tiêu: loop đọc token chuẩn.

# %%
#include <fstream>
#include <iostream>

int main() {
    const char* path = "ch19_nums.txt";

    // Ghi file số
    {
        std::ofstream out(path);
        out << "1 2 3 4 5";
    }

    std::ifstream in(path);
    if (!in) {
        std::cerr << "Open failed\n";
    } else {
        int x;
        long long sum = 0;
        while (in >> x) {
            sum += x;
        }

        std::cout << "sum = " << sum << "\n";
    }
    return 0;
}

# %% [markdown]
# #### Ví dụ 3 — Bẫy newline khi trộn `>>` và `getline`
# - Mục tiêu: nhớ dùng `std::ws` (hoặc ignore) trước getline.
# - Ta mô phỏng bằng `istringstream` để chạy ổn định.

# %%
#include <iostream>
#include <sstream>
#include <string>

int main() {
    std::istringstream in("10\nHello file I/O\n");

    int n;
    std::string line;

    in >> n;
    std::getline(in, line);
    std::cout << "(wrong) line='" << line << "'\n";

    in.clear();
    in.seekg(0);
    in >> n;
    std::getline(in >> std::ws, line);
    std::cout << "(right) line='" << line << "'\n";
    return 0;
}

# %% [markdown]
# #### Ví dụ 4 — Binary write/read (ios::binary)
# - Mục tiêu: nhớ mở mode binary khi đọc/ghi nhị phân.

# %%
#include <fstream>
#include <iostream>

int main() {
    const char* path = "ch19_bin.dat";

    int a[3] = {10, 20, 30};

    bool ok = true;

    // Write binary
    {
        std::ofstream out(path, std::ios::binary);
        if (!out) {
            std::cerr << "Open write failed\n";
            ok = false;
        } else {
            out.write(reinterpret_cast<const char*>(a), sizeof(a));
        }
    }

    int b[3] = {0};

    // Read binary
    if (ok) {
        std::ifstream in(path, std::ios::binary);
        if (!in) {
            std::cerr << "Open read failed\n";
            ok = false;
        } else {
            in.read(reinterpret_cast<char*>(b), sizeof(b));
        }
    }

    if (ok) {
        std::cout << b[0] << " " << b[1] << " " << b[2] << "\n";
    }
    return 0;
}

# %% [markdown]
# ### Luyện tập
# 1. Viết chương trình đếm số dòng trong file văn bản.
# 2. Ghi 10 số nguyên ra file ở chế độ nhị phân.
# 3. Khi nào cần dùng `std::ios::binary`?
#
# <details>
# <summary>Solution</summary>
#
# Gợi ý:
# - Dùng `std::getline` và đếm.
# - Dùng `write` với `ios::binary`.
# - Khi làm việc với dữ liệu nhị phân, tránh chuyển đổi newline.
# </details>

# %% [markdown]
# ### Lỗi thường gặp
# - Quên kiểm tra `in/out` sau khi mở file.
# - Quên thêm `std::ios::binary` khi đọc/ghi nhị phân.
# - Dùng `>>` làm mất khoảng trắng trong chuỗi.
#
# ### Tóm tắt
# - `<fstream>` cung cấp lớp file C++.
# - Đối tượng file tự đóng khi ra khỏi scope.
# - Dùng `ios::binary` cho dữ liệu nhị phân.
#
# ### Checkpoint quiz
# 1. `ifstream` dùng để làm gì?
# 2. Vì sao RAII hữu ích khi làm việc với file?
# 3. `std::getline` đọc theo đơn vị nào?
#
# <details>
# <summary>Đáp án</summary>
#
# 1. Đọc file.
# 2. Tự động đóng file khi ra khỏi scope.
# 3. Theo từng dòng.
# </details>

# %% [markdown]
# <a id="ch20"></a>
# ## Chương 20. Friend function/class
#
# **Prerequisites**
# - Chương 15 (class).
#
# **Learning outcomes**
# - Hiểu `friend` cho phép truy cập `private/protected` từ bên ngoài class.
# - Biết `friend` không đối xứng và không kế thừa.
# - Biết use-case hay thi: overload `operator<<` để in object.
# - Biết khi nào nên dùng và khi nào tránh dùng `friend`.
#
# ### Giải thích
#
# #### 1) `friend` là gì?
# Khi bạn khai báo một hàm (hoặc class) là `friend` của một class:
# - Hàm/class đó có quyền truy cập trực tiếp member `private/protected`.
#
# Lưu ý quan trọng:
# - `friend` **không** làm hàm trở thành member.
# - `friend` **không đối xứng**: A friend B không có nghĩa B friend A.
# - `friend` **không kế thừa**.
#
# #### 2) Khi nào nên dùng?
# Nên dùng khi:
# - Cần một hàm ngoài class thao tác sâu với dữ liệu mà không muốn mở public quá nhiều.
# - Thường gặp: `operator<<` để in object.
#
# Tránh dùng khi:
# - Bạn có thể giải quyết bằng public method/getter hợp lý.
#
# ### Ví dụ
#
# #### Ví dụ 1 — Friend function truy cập private
# - Mục tiêu: hiểu đúng “friend cho phép truy cập private”.

# %%
#include <iostream>

#ifndef CH20_RECT_DEFINED
#define CH20_RECT_DEFINED
class Rect20 {
private:
    double w;
    double h;

public:
    Rect20(double w_, double h_) : w(w_), h(h_) {}

    // friend function được truy cập w,h
    friend double area(const Rect20& r);
};

double area(const Rect20& r) {
    return r.w * r.h;
}
#endif

int main() {
    Rect20 r(3, 4);
    std::cout << "area = " << area(r) << "\n";
    return 0;
}

# %% [markdown]
# #### Ví dụ 2 — `operator<<` as friend (pattern rất hay thi)
# - Mục tiêu: viết operator<< để `cout << obj` được.
# - Bẫy: phải `return os;` để chain.

# %%
#include <iostream>

#ifndef CH20_POINT_DEFINED
#define CH20_POINT_DEFINED
struct Point20 {
private:
    int x;
    int y;

public:
    Point20(int x_, int y_) : x(x_), y(y_) {}

    friend std::ostream& operator<<(std::ostream& os, const Point20& p);
};

std::ostream& operator<<(std::ostream& os, const Point20& p) {
    os << "(" << p.x << "," << p.y << ")";
    return os;
}
#endif

int main() {
    Point20 p(1, 2);
    std::cout << "p = " << p << "\n";
    return 0;
}

# %% [markdown]
# #### Ví dụ 3 — Friend class (optional)
# - Mục tiêu: thấy một class khác có thể truy cập private.
# - Lưu ý: coupling mạnh, nên dùng hạn chế.

# %%
#include <iostream>

#ifndef CH20_FRIENDCLASS_DEFINED
#define CH20_FRIENDCLASS_DEFINED
class B20; // forward declaration

class A20 {
private:
    int secret = 123;
    friend class B20;
};

class B20 {
public:
    void reveal(const A20& a) {
        std::cout << "secret = " << a.secret << "\n";
    }
};
#endif

int main() {
    A20 a;
    B20 b;
    b.reveal(a);
    return 0;
}

# %% [markdown]
# ### Luyện tập
# 1. Viết `friend` function để so sánh diện tích hai hình chữ nhật.
# 2. Nêu một tình huống dùng `friend` hợp lý.
# 3. Vì sao `friend` làm giảm tính đóng gói?
#
# <details>
# <summary>Solution</summary>
#
# Gợi ý:
# - `bool larger(const Rectangle&, const Rectangle&)`.
# - Dùng khi cần thao tác liên quan nhiều lớp mà không muốn mở public quá nhiều.
# - Vì cho phép truy cập trực tiếp thành viên `private`.
# </details>

# %% [markdown]
# ### Lỗi thường gặp
# - Lạm dụng `friend` làm mất kiểm soát dữ liệu.
# - Nhầm `friend` là thành viên lớp.
# - Quên khai báo `friend` trong lớp.
#
# ### Tóm tắt
# - `friend` cho phép truy cập `private/protected`.
# - Dùng hạn chế và có mục đích rõ ràng.
# - Không phải là thành viên lớp.
#
# ### Checkpoint quiz
# 1. `friend` có tính đối xứng không?
# 2. Hàm friend có là thành viên lớp không?
# 3. Khi nào nên tránh dùng `friend`?
#
# <details>
# <summary>Đáp án</summary>
#
# 1. Không.
# 2. Không.
# 3. Khi có thể giải quyết bằng public method.
# </details>

# %% [markdown]
# <a id="review"></a>
# ## Tổng ôn theo format đề thi
#
# ### Dạng câu hỏi thường gặp
# 1. Trắc nghiệm về cú pháp: `main`, `printf`, `scanf`, `switch`, vòng lặp.
# 2. Trắc nghiệm về con trỏ: `*`, `&`, truyền tham số, swap, con trỏ hàm.
# 3. Trắc nghiệm về chuỗi: `\0`, `strlen`, `strcmp`, `fgets`.
# 4. File I/O: `FILE*`, `fopen` mode, `fclose`, `fprintf/fscanf`.
# 5. C++: reference, class, constructor/destructor, `virtual`, RAII.
# 6. STL: `vector`, `map`, template cơ bản.
#
# ### Dạng bài code
# 1. Đọc/ghi file và xử lý dữ liệu đơn giản.
# 2. Bài về mảng/chuỗi: đếm, tìm max/min, chuyển đổi ký tự.
# 3. Bài con trỏ: hoán đổi, cấp phát động.
# 4. Bài C++ OOP: lớp, kế thừa, đa hình.
#
# ### Lỗi hay gặp
# - Dùng `scanf` quên `&`.
# - Dùng `gets` gây tràn bộ đệm.
# - Quên `fclose` hoặc mở file sai mode.
# - Dùng `delete` thay cho `delete[]`.
# - Thiếu `virtual` trong đa hình.
#
# <details>
# <summary>Gợi ý cách ôn</summary>
#
# - Làm lại toàn bộ checkpoint quiz ở mỗi chương.
# - Với mỗi dạng bài, tự viết 1–2 chương trình ngắn và chạy thử.
# - Khi đọc code, luôn chú ý phạm vi biến, kiểu dữ liệu và thứ tự thực thi.
# </details>

# %% [markdown]
# ## Phân tích đề thật & Exam style rules
#
# ### Hình dáng câu hỏi (rút từ đề thật)
# - 100% trắc nghiệm 1 đáp án đúng, 4 lựa chọn A–D.
# - Hầu hết câu hỏi ở dạng **đọc code → dự đoán output/giá trị**.
# - Có một số câu hỏi lý thuyết ngắn (comment, toán tử, định nghĩa) và câu về công thức/đếm.
# - Câu hỏi thường ngắn, có code 3–10 dòng, ít giải thích.
#
# ### Độ khó & tỷ lệ (ước lượng)
# - Dễ ~35%: cú pháp cơ bản, toán tử, vòng lặp đơn giản.
# - Vừa ~50%: con trỏ, mảng/chuỗi, switch fall-through, toán tử bit, class cơ bản.
# - Khó ~15%: đa hình/virtual, ctor/dtor, template/STL ở mức cơ bản, bẫy tiền tố/hậu tố.
#
# ### Chủ đề lặp lại / trọng tâm
# - Con trỏ + tham chiếu, truyền tham số, swap.
# - Mảng/chuỗi, chỉ số, sizeof, xử lý ký tự.
# - Toán tử bit, dịch bit, kết hợp toán tử.
# - OOP C++: class, kế thừa, virtual, ctor/dtor.
# - Toán tử `?:`, `++/--`, switch fall-through, vòng lặp đếm.
#
# ### Phong cách ra đề
# - Ngắn gọn, trọng tâm thực hành.
# - Có bẫy nhỏ: tiền tố/hậu tố, fall-through, giá trị chưa khởi tạo.
# - Ưu tiên “đọc code → kết quả”.
#
# ### Exam style rules (quy tắc mô phỏng đề)
# 1. Mỗi câu **MCQ 4 lựa chọn A–D**, 1 đáp án đúng.
# 2. Ưu tiên câu **dự đoán output/giá trị** với code ngắn.
# 3. Có bẫy nhẹ ở mức hợp lý: `++/--`, `?:`, fall-through, sizeof/padding, pointer/array decay.
# 4. Hạn chế câu lý thuyết dài; nếu có thì 1–2 dòng.
# 5. Không dùng UB trừ khi đề thật có (khi đó đáp án là “Không xác định”).
# 6. Phân bố độ khó theo tỷ lệ 35% dễ – 50% vừa – 15% khó.

# %% [markdown]
# <a id="mini-mock-theo-chuong"></a>
# ## Mini-Mock theo chương
#
# > Chạy cell Python ngay bên dưới để kích hoạt trắc nghiệm tương tác.

# %%
import ipywidgets as w
from IPython.display import display, HTML
import html
import re
import json as _json
from pathlib import Path

RESULTS_PATH = Path.cwd() / '_mock_results.json'

STYLE = """
<style>
/* Force dark background around outputs in VS Code/Jupyter */
.output_container, .output, .output_area, .cell-output, .output_wrapper,
.jp-OutputArea-output, .jp-RenderedHTMLCommon, .vscode-notebook-cell-output,
.widget-area, .widget-subarea {
  background: #0b0b0b !important;
  color: #e6e6e6 !important;
}

.quiz-root { background: #0b0b0b; color: #e6e6e6; padding: 12px; border-radius: 8px; border: 1px solid #333; width: 100%; box-sizing: border-box; }
.quiz-topbar { margin: 4px 0 10px 0; }
.quiz-block { margin: 8px 0 18px 0; padding: 10px 12px; border: 1px solid #333; border-radius: 8px; background: #0b0b0b; color: #e6e6e6; }
.quiz-q { font-weight: 600; margin-bottom: 6px; color: #e6e6e6; }
.quiz-code { background: #111; color: #e6e6e6; padding: 10px; border-radius: 6px; border: 1px solid #333; }
.inline-code { background: #111; color: #ffd54f; padding: 1px 4px; border-radius: 4px; font-family: Consolas, Monaco, 'Courier New', monospace; }
.quiz-options { background: #0b0b0b; padding: 6px 8px; border-radius: 6px; border: 1px solid #222; }
.quiz-options .widget-label { color: #e6e6e6 !important; }
.quiz-options label { color: #e6e6e6 !important; }
.quiz-options input { accent-color: #22c55e; }
.quiz-close .widget-button { background: #dc2626 !important; color: #fff !important; border: 1px solid #7f1d1d !important; border-radius: 8px !important; }
.quiz-topbar .widget-togglebutton { border-radius: 8px !important; overflow: hidden; }
.quiz-topbar .widget-togglebutton > button { border-radius: 8px !important; }
.quiz-topbar .widget-button { border-radius: 8px !important; }
</style>
"""

def load_results():
    try:
        if RESULTS_PATH.exists():
            return _json.loads(RESULTS_PATH.read_text(encoding='utf-8'))
    except Exception:
        pass
    return {}

def save_results(data):
    try:
        RESULTS_PATH.write_text(_json.dumps(data, ensure_ascii=False, indent=2), encoding='utf-8')
    except Exception:
        pass

def render_inline_code(text: str) -> str:
    parts = text.split('`')
    out = []
    for i, part in enumerate(parts):
        if i % 2 == 0:
            out.append(html.escape(part))
        else:
            out.append(f"<code class='inline-code'>{html.escape(part)}</code>")
    return ''.join(out)

def clean_option_text(text: str) -> str:
    return re.sub(r'`([^`]*)`', r'\1', text)

def render_mock(title, questions):
    display(HTML(STYLE))
    results = load_results()
    key = title
    saved = results.get(key)

    header = w.HTML(f"<h4 style='margin: 0 0 8px 0; color:#e6e6e6'>{html.escape(title)}</h4>")

    mode = w.ToggleButtons(
        options=[('Chấm ngay', 'auto'), ('Làm hết rồi chấm', 'submit')],
        value='auto'
    )
    submit_btn = w.Button(description='Chấm và lưu', button_style='success', icon='check')
    submit_btn.layout.display = 'none'
    reset_btn = w.Button(description='Làm lại', button_style='warning', icon='refresh')
    reset_btn.layout.display = '' if saved else 'none'

    topbar = w.HBox([mode, submit_btn, reset_btn], layout=w.Layout(justify_content='space-between', align_items='center'))
    topbar.add_class('quiz-topbar')

    blocks = [header, topbar]
    items = []

    for q in questions:
        q_text = f"Câu {q['num']}. {q['q']}"
        q_html = w.HTML(f"<div class='quiz-q'>{render_inline_code(q_text)}</div>")
        parts = [q_html]

        if q.get('code'):
            style = q.get('code_style', 'block') or 'block'
            if style == 'inline':
                lines_inline = q['code'].splitlines() or [q['code']]
                html_lines = "".join([f"<code class='inline-code'>{html.escape(x)}</code><br>" for x in lines_inline if x != ""])
                parts.append(w.HTML(f"<div>{html_lines}</div>"))
            else:
                code_html = "<pre class='quiz-code'><code>" + html.escape(q['code']) + "</code></pre>"
                parts.append(w.HTML(code_html))

        opts = [(f"{k}. {clean_option_text(v)}", k) for k, v in q['options']]
        radio = w.RadioButtons(options=opts, value=None, layout=w.Layout(width='auto'))
        radio.add_class('quiz-options')
        fb = w.HTML("")

        def mark_answer(radio, fb, q):
            if radio.value is None:
                fb.value = "<span style='color:#ef4444'>Sai. Đáp án đúng: {}.</span>".format(q['answer'])
            elif radio.value == q['answer']:
                fb.value = "<span style='color:#22c55e'>Đúng.</span>"
            else:
                expl = q.get('explain','')
                expl = render_inline_code(expl) if expl else ''
                fb.value = f"<span style='color:#ef4444'>Sai. Đáp án đúng: {q['answer']}. {expl}</span>"

        def persist(graded=True):
            data = load_results()
            data[key] = {
                'mode': mode.value,
                'graded': graded,
                'answers': {str(q['num']): radio.value for radio, _, q in items}
            }
            save_results(data)

        def on_change(change, q=q, fb=fb, radio=radio):
            if change.get('name') != 'value':
                return
            if mode.value != 'auto':
                return
            if radio.value is None:
                fb.value = ""
            elif radio.value == q['answer']:
                fb.value = "<span style='color:#22c55e'>Đúng.</span>"
            else:
                expl = q.get('explain','')
                expl = render_inline_code(expl) if expl else ''
                fb.value = f"<span style='color:#ef4444'>Sai. Đáp án đúng: {q['answer']}. {expl}</span>"
            persist(graded=True)

        radio.observe(on_change)
        parts.extend([radio, fb])

        block = w.VBox(parts, layout=w.Layout(margin='6px 0 12px 0'))
        block.add_class('quiz-block')
        blocks.append(block)
        items.append((radio, fb, q))

    if saved:
        mode.value = saved.get('mode', 'auto')
        ans_map = saved.get('answers', {})
        for radio, fb, q in items:
            radio.value = ans_map.get(str(q['num']))
            mark_answer(radio, fb, q)
            radio.disabled = True
        mode.disabled = True
        submit_btn.disabled = True

    def on_submit(_):
        for radio, fb, q in items:
            mark_answer(radio, fb, q)
        persist(graded=True)
        reset_btn.layout.display = ''
        for radio, _, _ in items:
            radio.disabled = True
        mode.disabled = True
        submit_btn.disabled = True

    submit_btn.on_click(on_submit)

    def on_mode_change(change):
        if change.get('name') != 'value':
            return
        if mode.value == 'auto':
            submit_btn.layout.display = 'none'
        else:
            submit_btn.layout.display = ''
            for _, fb, _ in items:
                fb.value = ""

    mode.observe(on_mode_change)

    def on_reset(_):
        data = load_results()
        if key in data:
            data.pop(key)
            save_results(data)
        for radio, fb, _ in items:
            radio.value = None
            radio.disabled = False
            fb.value = ""
        mode.disabled = False
        mode.value = 'auto'
        submit_btn.disabled = False
        submit_btn.layout.display = 'none'
        reset_btn.layout.display = 'none'

    reset_btn.on_click(on_reset)

    close_btn = w.Button(description='Đóng mock', button_style='danger', icon='times')
    close_btn.layout = w.Layout(width='100%')
    close_btn.add_class('quiz-close')

    root = w.VBox(blocks + [close_btn], layout=w.Layout(width='100%', margin='0'))
    root.add_class('quiz-root')

    out = w.Output()
    def do_close(_):
        out.clear_output()
    close_btn.on_click(do_close)

    with out:
        display(root)
    display(out)

# %% [markdown]
# <a id="mock-chuong-1-15-cau"></a>
# ### Mock Chương 1 (15 câu)
#
# **Thời gian gợi ý:** 20–25 phút
#
# **Hướng dẫn:** Chọn đáp án, rồi bấm **Chấm** để xem đúng/sai.

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Chương 1 (15 câu)")
render_mock("Mock Chương 1 (15 câu)", questions)
# Out:
# <style>
# /* Force dark background around outputs in VS Code/Jupyter */
# .output_container, .output, .output_area, .cell-output, .output_wrapper,
# .jp-OutputArea-output, .jp-RenderedHTMLCommon, .vscode-notebook-cell-output,
# .widget-area, .widget-subarea {
#   background: #0b0b0b !important;
#   color: #e6e6e6 !important;
# }
#
# .quiz-root { background: #0b0b0b; color: #e6e6e6; padding: 12px; border-radius: 8px; border: 1px solid #333; width: 100%; box-sizing: border-box; }
# .quiz-topbar { margin: 4px 0 10px 0; }
# .quiz-block { margin: 8px 0 18px 0; padding: 10px 12px; border: 1px solid #333; border-radius: 8px; background: #0b0b0b; color: #e6e6e6; }
# .quiz-q { font-weight: 600; margin-bottom: 6px; color: #e6e6e6; }
# .quiz-code { background: #111; color: #e6e6e6; padding: 10px; border-radius: 6px; border: 1px solid #333; }
# .inline-code { background: #111; color: #ffd54f; padding: 1px 4px; border-radius: 4px; font-family: Consolas, Monaco, 'Courier New', monospace; }
# ...

# %% [markdown]
# <a id="mock-chuong-2-15-cau"></a>
# ### Mock Chương 2 (15 câu)
#
# **Thời gian gợi ý:** 20–25 phút
#
# **Hướng dẫn:** Chọn đáp án, rồi bấm **Chấm** để xem đúng/sai.

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Chương 2 (15 câu)")
render_mock("Mock Chương 2 (15 câu)", questions)
# Out:
# <style>
# /* Force dark background around outputs in VS Code/Jupyter */
# .output_container, .output, .output_area, .cell-output, .output_wrapper,
# .jp-OutputArea-output, .jp-RenderedHTMLCommon, .vscode-notebook-cell-output,
# .widget-area, .widget-subarea {
#   background: #0b0b0b !important;
#   color: #e6e6e6 !important;
# }
#
# .quiz-root { background: #0b0b0b; color: #e6e6e6; padding: 12px; border-radius: 8px; border: 1px solid #333; width: 100%; box-sizing: border-box; }
# .quiz-topbar { margin: 4px 0 10px 0; }
# .quiz-block { margin: 8px 0 18px 0; padding: 10px 12px; border: 1px solid #333; border-radius: 8px; background: #0b0b0b; color: #e6e6e6; }
# .quiz-q { font-weight: 600; margin-bottom: 6px; color: #e6e6e6; }
# .quiz-code { background: #111; color: #e6e6e6; padding: 10px; border-radius: 6px; border: 1px solid #333; }
# .inline-code { background: #111; color: #ffd54f; padding: 1px 4px; border-radius: 4px; font-family: Consolas, Monaco, 'Courier New', monospace; }
# ...

# %% [markdown]
# <a id="mock-chuong-3-15-cau"></a>
# ### Mock Chương 3 (15 câu)
#
# **Thời gian gợi ý:** 20–25 phút
#
# **Hướng dẫn:** Chọn đáp án, rồi bấm **Chấm** để xem đúng/sai.

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Chương 3 (15 câu)")
render_mock("Mock Chương 3 (15 câu)", questions)

# %% [markdown]
# <a id="mock-chuong-4-15-cau"></a>
# ### Mock Chương 4 (15 câu)
#
# **Thời gian gợi ý:** 20–25 phút
#
# **Hướng dẫn:** Chọn đáp án, rồi bấm **Chấm** để xem đúng/sai.

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Chương 4 (15 câu)")
render_mock("Mock Chương 4 (15 câu)", questions)

# %% [markdown]
# <a id="mock-chuong-5-15-cau"></a>
# ### Mock Chương 5 (15 câu)
#
# **Thời gian gợi ý:** 20–25 phút
#
# **Hướng dẫn:** Chọn đáp án, rồi bấm **Chấm** để xem đúng/sai.

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Chương 5 (15 câu)")
render_mock("Mock Chương 5 (15 câu)", questions)

# %% [markdown]
# <a id="mock-chuong-6-15-cau"></a>
# ### Mock Chương 6 (15 câu)
#
# **Thời gian gợi ý:** 20–25 phút
#
# **Hướng dẫn:** Chọn đáp án, rồi bấm **Chấm** để xem đúng/sai.

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Chương 6 (15 câu)")
render_mock("Mock Chương 6 (15 câu)", questions)

# %% [markdown]
# <a id="mock-chuong-7-15-cau"></a>
# ### Mock Chương 7 (15 câu)
#
# **Thời gian gợi ý:** 20–25 phút
#
# **Hướng dẫn:** Chọn đáp án, rồi bấm **Chấm** để xem đúng/sai.

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Chương 7 (15 câu)")
render_mock("Mock Chương 7 (15 câu)", questions)

# %% [markdown]
# <a id="mock-chuong-8-15-cau"></a>
# ### Mock Chương 8 (15 câu)
#
# **Thời gian gợi ý:** 20–25 phút
#
# **Hướng dẫn:** Chọn đáp án, rồi bấm **Chấm** để xem đúng/sai.

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Chương 8 (15 câu)")
render_mock("Mock Chương 8 (15 câu)", questions)

# %% [markdown]
# <a id="mock-chuong-9-15-cau"></a>
# ### Mock Chương 9 (15 câu)
#
# **Thời gian gợi ý:** 20–25 phút
#
# **Hướng dẫn:** Chọn đáp án, rồi bấm **Chấm** để xem đúng/sai.

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Chương 9 (15 câu)")
render_mock("Mock Chương 9 (15 câu)", questions)

# %% [markdown]
# <a id="mock-chuong-10-15-cau"></a>
# ### Mock Chương 10 (15 câu)
#
# **Thời gian gợi ý:** 20–25 phút
#
# **Hướng dẫn:** Chọn đáp án, rồi bấm **Chấm** để xem đúng/sai.

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Chương 10 (15 câu)")
render_mock("Mock Chương 10 (15 câu)", questions)

# %% [markdown]
# <a id="mock-chuong-11-15-cau"></a>
# ### Mock Chương 11 (15 câu)
#
# **Thời gian gợi ý:** 20–25 phút
#
# **Hướng dẫn:** Chọn đáp án, rồi bấm **Chấm** để xem đúng/sai.

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Chương 11 (15 câu)")
render_mock("Mock Chương 11 (15 câu)", questions)

# %% [markdown]
# <a id="mock-chuong-12-15-cau"></a>
# ### Mock Chương 12 (15 câu)
#
# **Thời gian gợi ý:** 20–25 phút
#
# **Hướng dẫn:** Chọn đáp án, rồi bấm **Chấm** để xem đúng/sai.

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Chương 12 (15 câu)")
render_mock("Mock Chương 12 (15 câu)", questions)

# %% [markdown]
# <a id="mock-chuong-13-15-cau"></a>
# ### Mock Chương 13 (15 câu)
#
# **Thời gian gợi ý:** 20–25 phút
#
# **Hướng dẫn:** Chọn đáp án, rồi bấm **Chấm** để xem đúng/sai.

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Chương 13 (15 câu)")
render_mock("Mock Chương 13 (15 câu)", questions)

# %% [markdown]
# <a id="mock-chuong-14-15-cau"></a>
# ### Mock Chương 14 (15 câu)
#
# **Thời gian gợi ý:** 20–25 phút
#
# **Hướng dẫn:** Chọn đáp án, rồi bấm **Chấm** để xem đúng/sai.

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Chương 14 (15 câu)")
render_mock("Mock Chương 14 (15 câu)", questions)

# %% [markdown]
# <a id="mock-chuong-15-15-cau"></a>
# ### Mock Chương 15 (15 câu)
#
# **Thời gian gợi ý:** 20–25 phút
#
# **Hướng dẫn:** Chọn đáp án, rồi bấm **Chấm** để xem đúng/sai.

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Chương 15 (15 câu)")
render_mock("Mock Chương 15 (15 câu)", questions)

# %% [markdown]
# <a id="mock-chuong-16-15-cau"></a>
# ### Mock Chương 16 (15 câu)
#
# **Thời gian gợi ý:** 20–25 phút
#
# **Hướng dẫn:** Chọn đáp án, rồi bấm **Chấm** để xem đúng/sai.

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Chương 16 (15 câu)")
render_mock("Mock Chương 16 (15 câu)", questions)

# %% [markdown]
# <a id="mock-chuong-17-15-cau"></a>
# ### Mock Chương 17 (15 câu)
#
# **Thời gian gợi ý:** 20–25 phút
#
# **Hướng dẫn:** Chọn đáp án, rồi bấm **Chấm** để xem đúng/sai.

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Chương 17 (15 câu)")
render_mock("Mock Chương 17 (15 câu)", questions)

# %% [markdown]
# <a id="mock-chuong-18-15-cau"></a>
# ### Mock Chương 18 (15 câu)
#
# **Thời gian gợi ý:** 20–25 phút
#
# **Hướng dẫn:** Chọn đáp án, rồi bấm **Chấm** để xem đúng/sai.

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Chương 18 (15 câu)")
render_mock("Mock Chương 18 (15 câu)", questions)

# %% [markdown]
# <a id="mock-chuong-19-15-cau"></a>
# ### Mock Chương 19 (15 câu)
#
# **Thời gian gợi ý:** 20–25 phút
#
# **Hướng dẫn:** Chọn đáp án, rồi bấm **Chấm** để xem đúng/sai.

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Chương 19 (15 câu)")
render_mock("Mock Chương 19 (15 câu)", questions)

# %% [markdown]
# <a id="mock-chuong-20-15-cau"></a>
# ### Mock Chương 20 (15 câu)
#
# **Thời gian gợi ý:** 20–25 phút
#
# **Hướng dẫn:** Chọn đáp án, rồi bấm **Chấm** để xem đúng/sai.

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Chương 20 (15 câu)")
render_mock("Mock Chương 20 (15 câu)", questions)

# %% [markdown]
# <a id="mini-mock-tong-hop"></a>
# ## Mini-Mock tổng hợp
#
# > Nếu chưa chạy helper ở trên, hãy chạy lại cell helper để kích hoạt trắc nghiệm.

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Quiz")
render_mock("Mock Quiz", questions)

# %% [markdown]
# <a id="mock-tong-hop-1-40-cau"></a>
# ### Mock Tổng Hợp 1 (40 câu)
#
# **Thời gian gợi ý:** 75 phút
#
# **Hướng dẫn:** Chọn đáp án, rồi bấm **Chấm** để xem đúng/sai.
#
#
# **Bảng phân bố nội dung (ước lượng)**
#
#
# | Chương | Số câu |
# | --- | --- |
#
# | Chương 1 | 1 |
#
# | Chương 2 | 2 |
#
# | Chương 3 | 2 |
#
# | Chương 4 | 3 |
#
# | Chương 5 | 1 |
#
# | Chương 6 | 3 |
#
# | Chương 7 | 3 |
#
# | Chương 8 | 3 |
#
# | Chương 9 | 3 |
#
# | Chương 10 | 3 |
#
# | Chương 11 | 1 |
#
# | Chương 12 | 1 |
#
# | Chương 13 | 3 |
#
# | Chương 14 | 3 |
#
# | Chương 15 | 1 |
#
# | Chương 16 | 1 |
#
# | Chương 17 | 3 |
#
# | Chương 18 | 1 |
#
# | Chương 19 | 1 |
#
# | Chương 20 | 1 |

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Tổng Hợp 1 (40 câu)")
render_mock("Mock Tổng Hợp 1 (40 câu)", questions)

# %% [markdown]
# <a id="mock-tong-hop-2-40-cau"></a>
# ### Mock Tổng Hợp 2 (40 câu)
#
# **Thời gian gợi ý:** 75 phút
#
# **Hướng dẫn:** Chọn đáp án, rồi bấm **Chấm** để xem đúng/sai.
#
#
# **Bảng phân bố nội dung (ước lượng)**
#
#
# | Chương | Số câu |
# | --- | --- |
#
# | Chương 1 | 1 |
#
# | Chương 2 | 2 |
#
# | Chương 3 | 2 |
#
# | Chương 4 | 3 |
#
# | Chương 5 | 1 |
#
# | Chương 6 | 3 |
#
# | Chương 7 | 3 |
#
# | Chương 8 | 3 |
#
# | Chương 9 | 3 |
#
# | Chương 10 | 3 |
#
# | Chương 11 | 1 |
#
# | Chương 12 | 1 |
#
# | Chương 13 | 3 |
#
# | Chương 14 | 3 |
#
# | Chương 15 | 1 |
#
# | Chương 16 | 1 |
#
# | Chương 17 | 3 |
#
# | Chương 18 | 1 |
#
# | Chương 19 | 1 |
#
# | Chương 20 | 1 |

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Tổng Hợp 2 (40 câu)")
render_mock("Mock Tổng Hợp 2 (40 câu)", questions)

# %% [markdown]
# <a id="mock-tong-hop-3-40-cau"></a>
# ### Mock Tổng Hợp 3 (40 câu)
#
# **Thời gian gợi ý:** 75 phút
#
# **Hướng dẫn:** Chọn đáp án, rồi bấm **Chấm** để xem đúng/sai.
#
#
# **Bảng phân bố nội dung (ước lượng)**
#
#
# | Chương | Số câu |
# | --- | --- |
#
# | Chương 1 | 1 |
#
# | Chương 2 | 2 |
#
# | Chương 3 | 2 |
#
# | Chương 4 | 3 |
#
# | Chương 5 | 1 |
#
# | Chương 6 | 3 |
#
# | Chương 7 | 3 |
#
# | Chương 8 | 3 |
#
# | Chương 9 | 3 |
#
# | Chương 10 | 3 |
#
# | Chương 11 | 1 |
#
# | Chương 12 | 1 |
#
# | Chương 13 | 3 |
#
# | Chương 14 | 3 |
#
# | Chương 15 | 1 |
#
# | Chương 16 | 1 |
#
# | Chương 17 | 3 |
#
# | Chương 18 | 1 |
#
# | Chương 19 | 1 |
#
# | Chương 20 | 1 |

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Tổng Hợp 3 (40 câu)")
render_mock("Mock Tổng Hợp 3 (40 câu)", questions)

# %% [markdown]
# <a id="mock-tong-hop-4-40-cau"></a>
# ### Mock Tổng Hợp 4 (40 câu)
#
# **Thời gian gợi ý:** 75 phút
#
# **Hướng dẫn:** Chọn đáp án, rồi bấm **Chấm** để xem đúng/sai.
#
#
# **Bảng phân bố nội dung (ước lượng)**
#
#
# | Chương | Số câu |
# | --- | --- |
#
# | Chương 1 | 1 |
#
# | Chương 2 | 2 |
#
# | Chương 3 | 2 |
#
# | Chương 4 | 3 |
#
# | Chương 5 | 1 |
#
# | Chương 6 | 3 |
#
# | Chương 7 | 3 |
#
# | Chương 8 | 3 |
#
# | Chương 9 | 3 |
#
# | Chương 10 | 3 |
#
# | Chương 11 | 1 |
#
# | Chương 12 | 1 |
#
# | Chương 13 | 3 |
#
# | Chương 14 | 3 |
#
# | Chương 15 | 1 |
#
# | Chương 16 | 1 |
#
# | Chương 17 | 3 |
#
# | Chương 18 | 1 |
#
# | Chương 19 | 1 |
#
# | Chương 20 | 1 |

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Tổng Hợp 4 (40 câu)")
render_mock("Mock Tổng Hợp 4 (40 câu)", questions)

# %% [markdown]
# <a id="mock-tong-hop-5-40-cau"></a>
# ### Mock Tổng Hợp 5 (40 câu)
#
# **Thời gian gợi ý:** 75 phút
#
# **Hướng dẫn:** Chọn đáp án, rồi bấm **Chấm** để xem đúng/sai.
#
#
# **Bảng phân bố nội dung (ước lượng)**
#
#
# | Chương | Số câu |
# | --- | --- |
#
# | Chương 1 | 1 |
#
# | Chương 2 | 2 |
#
# | Chương 3 | 2 |
#
# | Chương 4 | 3 |
#
# | Chương 5 | 1 |
#
# | Chương 6 | 3 |
#
# | Chương 7 | 3 |
#
# | Chương 8 | 3 |
#
# | Chương 9 | 3 |
#
# | Chương 10 | 3 |
#
# | Chương 11 | 1 |
#
# | Chương 12 | 1 |
#
# | Chương 13 | 3 |
#
# | Chương 14 | 3 |
#
# | Chương 15 | 1 |
#
# | Chương 16 | 1 |
#
# | Chương 17 | 3 |
#
# | Chương 18 | 1 |
#
# | Chương 19 | 1 |
#
# | Chương 20 | 1 |

# %%
import json as _json
try:
    render_mock
except NameError:
    from _mock_helper import render_mock
from _mock_bank import get_questions

questions = get_questions("Mock Tổng Hợp 5 (40 câu)")
render_mock("Mock Tổng Hợp 5 (40 câu)", questions)
